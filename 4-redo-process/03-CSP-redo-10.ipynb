# %%
import pandas
import numpy as np
from utils import *
import mne
import matplotlib.pyplot as plt
from os import walk
from sklearn.decomposition import FastICA
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.model_selection import cross_val_score
from itertools import combinations
from sklearn.preprocessing import normalize
from sklearn.utils import shuffle
from tqdm.notebook import tqdm
import pickle

from multiprocessing import Pool
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# # Groud truth - Median

# %%
df = pandas.read_csv('./HEXACO.csv')
# Honesty-Humility	Emotionality	eXtraversion	Agreeableness	Conscientiousness	Openness to Experience
gt = df[['id','Honesty-Humility','Emotionality','eXtraversion','Agreeableness','Conscientiousness','Openness to Experience']].rename(columns={'Honesty-Humility':'h',
                                  'Emotionality':'e',
                                  'eXtraversion':'x',
                                 'Agreeableness':'a',
                             'Conscientiousness':'c',
                        'Openness to Experience':'o'}).set_index('id')

gt['lh'] = (gt[['h']] > np.median(gt['h'])) * 1
gt['le'] = (gt[['e']] > np.median(gt['e'])) * 1
gt['lx'] = (gt[['x']] > np.median(gt['x'])) * 1
gt['la'] = (gt[['a']] > np.median(gt['a'])) * 1
gt['lc'] = (gt[['c']] > np.median(gt['c'])) * 1
gt['lo'] = (gt[['o']] > np.median(gt['o'])) * 1
gt
# Out:
#        h     e     x     a     c     o  lh  le  lx  la  lc  lo
# id
# 2   3.63  3.19  2.94  2.38  3.38  2.38   1   0   0   0   0   0
# 3   3.38  3.44  3.50  3.50  4.50  3.81   0   0   1   1   1   1
# 4   3.19  3.75  3.69  3.19  2.63  2.63   0   1   1   0   0   0
# 5   3.25  3.63  2.13  3.56  3.63  2.31   0   1   0   1   1   0
# 6   3.25  2.75  3.50  2.50  3.75  5.00   0   0   1   0   1   1
# 7   4.06  3.06  3.38  2.88  2.50  4.19   1   0   1   0   0   1
# 8   3.94  2.94  3.19  3.75  3.38  3.81   1   0   1   1   0   1
# 9   4.44  4.00  3.38  3.75  3.69  3.31   1   1   1   1   1   0
# 10  3.63  3.25  3.50  3.31  3.88  2.69   1   0   1   1   1   0
# 11  3.31  4.00  2.25  3.19  2.81  3.19   0   1   0   0   0   0
# 12  2.81  3.44  3.13  3.56  3.25  3.75   0   0   1   1   0   1
# 13  3.06  3.06  3.00  2.69  3.31  3.44   0   0   0   0   0   0
# 14  4.63  3.69  2.25  3.13  2.94  2.63   1   1   0   0   0   0
# 15  3.75  2.94  2.94  3.50  4.19  3.19   1   0   0   1   1   0
# 16  4.19  4.25  1.88  2.81  3.25  3.81   1   1   0   0   0   1
# 17  4.25  3.00  4.00  2.50  3.25  3.25   1   0   1   0   0   0
# 18  2.81  3.31  2.06  2.75  3.00  3.19   0   0   0   0   0   0
# 20  3.25  3.31  4.31  3.44  2.00  4.25   0   0   1   1   0   1
# 21  4.06  3.00  2.88  3.56  3.81  3.81   1   0   0   1   1   1
# 22  3.50  3.88  1.88  2.63  3.94  3.69   0   1   0   0   1   1
# 23  3.13  4.19  3.00  2.38  2.88  3.88   0   1   0   0   0   1
# 25  3.25  3.44  3.75  3.50  3.88  3.44   0   0   1   1   1   0
# 26  3.50  3.19  2.44  2.94  2.44  3.25   0   0   0   0   0   0
# 27  2.63  3.88  3.81  3.88  3.31  3.88   0   1   1   1   0   1
# 28  3.19  4.31  2.19  1.88  2.56  3.25   0   1   0   0   0   0
# 29  3.56  4.38  2.06  2.94  3.44  4.56   1   1   0   0   1   1
# 30  4.50  3.81  2.44  3.13  2.94  4.31   1   1   0   0   0   1
# 31  4.06  3.56  2.63  3.31  3.75  4.06   1   1   0   1   1   1
# 32  2.75  3.25  3.75  2.81  3.06  3.31   0   0   1   0   0   0
# 33  4.00  3.56  2.38  3.63  3.63  3.19   1   1   0   1   1   0
# 34  3.38  2.69  3.69  3.31  3.81  3.50   0   0   1   1   1   0
# 35  3.69  3.44  3.56  4.00  3.38  4.38   1   0   1   1   0   1
# 36  3.56  4.56  3.31  3.63  4.38  4.31   1   1   1   1   1   1

# %%
fig, ax = plt.subplots(figsize=(16,9))
ax.bar(['H','E','X','A','C','O'],[ sum(gt['lh']), sum(gt['le']), sum(gt['lx']), sum(gt['la']), sum(gt['lc']), sum(gt['lo'])  ])
ax.set_title("Distribution of Labels")
ax.set_xlabel("Labels")
# ax.set_ylabel("Distribution of Labels")
plt.show()

# %% [markdown]
# # EEG data

# %%
def load_data():
    path, folders, filenames = next(walk('./data'))

    filenames.remove('11-audio.csv')
    filenames.remove('11-image.csv')

    filenames.remove('36-audio.csv')
    filenames.remove('36-image.csv')

    path = './data'
    columns = {'Unnamed: 1':'Fp1',
            'Unnamed: 2':'Fp2',
            'Unnamed: 3':'F3',
            'Unnamed: 4':'F4',
            'Unnamed: 5':'F7',
            'Unnamed: 6':'F8',
            'Unnamed: 7':'P7',
            'Unnamed: 8':'P8'}

    EEG_audio, EEG_image = dict(), dict()
    from itertools import product
    categories = [1,2,3,4,5]
    blocks = [1,2]
    with tqdm(filenames) as t:
        for filename in t:
            t.set_description(f"{filename}")
            participant_id, stimuli = filename.split('-')
            stimuli = stimuli.rstrip('.csv')
            data = pandas.read_csv(f'{path}/{filename}', dtype={'Marker': str}).rename(columns=columns).drop(columns='timestamps')
            # Aviod warning on stim has negative value
            marker = np.array(data['Marker'])
            marker[marker == '-1'] = '1'
            data['Marker'] = marker

            if(stimuli == 'audio'):
                EEG_audio[int(participant_id)] = data
            elif(stimuli == 'image'):
                EEG_image[int(participant_id)] = data
            else:
                raise ValueError(f"Stimuli:{stimuli} is unexpected.")
    return EEG_audio, EEG_image

# %%
# clear_cache()
try:
    # Load from cache
    EEG_audio = load('EEG_audio')
    EEG_image = load('EEG_image')
    print('Load data from cache')
    if( set(EEG_audio.keys()) != set(EEG_image.keys()) ):
        extra = None
        if(len(EEG_audio.keys()) > len(EEG_image.keys())):
            extra = set(EEG_audio.keys()).difference( set(EEG_image.keys()) )
        else:
            extra = set(EEG_image.keys()).difference( set(EEG_audio.keys()) )
        raise ValueError(f"In equal keys. audio has {len(EEG_audio.keys())} and image has {len(EEG_image.keys())}. The extra key is {extra}")

except FileNotFoundError as e:
    EEG_audio, EEG_image = load_data()
    # Save to cache
    save(EEG_audio, 'EEG_audio')
    save(EEG_image, 'EEG_image')
# Out:
# Load data from cache

# %% [markdown]
# # Pre process with PSD + log + mne ICA

# %%
# raw = dataframe_to_raw(EEG_image[33], sfreq=250)

# # Preprocess
# raw.notch_filter([50,100],filter_length='auto', phase='zero', verbose=False) # Line power
# raw.filter(1., None, verbose=False) # Slow drift

# events = mne.find_events(raw, stim_channel='Marker', initial_event=True, verbose=False, uint_cast=False)
# events = np.delete(events,np.argwhere(events[:,2] == 1), axis=0) # break
# # Check data
# if(events.shape[0] != 50):
#     raise ValueError(f"Event missing: {events[:,2]}. len(events.shape[0])={events.shape[0]}")
# epochs = mne.Epochs(raw, events, tmin=0.3, tmax=5.8, baseline=(0.3,0.3), verbose=False)
# if(epochs.get_data().shape[0] != 50):
#     raise ValueError(f"There might be a bad data. epochs.get_data().shape = {epochs.get_data().shape}")

# # for evoked in epochs.iter_evoked():
# #     reduc = ica.apply(evoked, verbose=False)
# #     power,freq = mne.time_frequency.psd_array_welch(reduc.data[:6],sfreq=250,n_fft=128, verbose=False)
# #     break

# %%
# # Extract features
# events = np.array([int(event / 100) for event in epochs.events[:,2]])
# Y = None
# X = None
# csp = mne.decoding.CSP(n_components=8, transform_into='csp_space', norm_trace=True)
# data = csp.fit_transform(epochs.get_data()[:,:8,:], events)
# print(data.shape)
# for index, evoked in enumerate(epochs.iter_evoked()):
#     # event = int(evoked.comment[0])
#     # events.append(event)
#     power,freq = mne.time_frequency.psd_array_welch(data[index],sfreq=250,n_fft=128, verbose=False)
#     row = power
#     row = np.expand_dims(row, axis=0)
#     row = 10 * np.log10(row)
#     if(type(X) == type(None)): X = row
#     else: X = np.concatenate( [X, row ], axis=0 )

#     label = gt.loc[33][['lh','le','lx','la','lc','lo']].to_numpy()
#     label = np.expand_dims(label, axis=0)
#     if(type(Y) == type(None)): Y = label
#     else: Y = np.concatenate( [Y, label ], axis=0 )
# print(events.shape, X.shape, Y.shape)

# %%
# data = X.copy().reshape(50,-1)
# # data
# print(data.shape)
# data_norm = normalize(data.copy(), axis=0)
# mnb = GaussianNB()
# mnb.fit(data_norm, events)
# acc = sum(mnb.predict(data_norm) == events) / len(events)
# scores = cross_val_score(mnb, data_norm, events)
# print(acc, scores)

# %%
# proj_data.shape

# %%
band_names = np.array(['Delta', 'Theta', 'Alpha', 'Beta', 'Gamma'])
filter_list = [[0,4],[4,8],[8,13],[13,30],[30,125]]
def build_data(p_num, EEG,ids):
    X = None
    Y = None
    t_start, t_stop = (2.0,4.0)
    with tqdm(ids) as t:
        for index, id in enumerate(t):
            t.set_description(f"{id}")
            print(f"p_no={p_num}|index={index}|id={id}")
            raw = dataframe_to_raw(EEG[id], sfreq=250)
            
            # Preprocess
            raw.notch_filter([50,100],filter_length='auto', phase='zero', verbose=False) # Line power
            raw.filter(1., None, verbose=False) # Slow drift
            # ica = mne.preprocessing.ICA(n_components=8, max_iter='auto')
            # ica.fit(raw, verbose=False)
            # raw = ica.apply(raw, verbose=False)

            events = mne.find_events(raw, stim_channel='Marker', initial_event=True, verbose=False, uint_cast=False)
            events = np.delete(events,np.argwhere(events[:,2] == 1), axis=0) # break
            # Check data
            if(events.shape[0] != 50):
                raise ValueError(f"Event missing: {events[:,2]}. len(events.shape[0])={events.shape[0]}")
            epochs = mne.Epochs(raw, events, tmin=t_start, tmax=t_stop, baseline=(t_start,t_stop), verbose=False)
            if(epochs.get_data().shape[0] != 50):
                raise ValueError(f"There might be a bad data. epochs.get_data().shape = {epochs.get_data().shape}")

            # Extract features
            events = np.array([int(event / 100) for event in epochs.events[:,2]])
            csp = mne.decoding.CSP(n_components=10, transform_into='csp_space', norm_trace=True)
            data = csp.fit_transform(epochs.get_data()[:,:8,:], events)
            for index_inner, evoked in enumerate(epochs.iter_evoked()):
                power,freq = mne.time_frequency.psd_array_welch(data[index_inner],sfreq=250,n_fft=128, verbose=False)
                row = power
                row = np.expand_dims(row, axis=0)
                row = 10 * np.log10(row)
                if(type(X) == type(None)): X = row
                else: X = np.concatenate( [X, row ], axis=0 )

                label = gt.loc[id][['lh','le','lx','la','lc','lo']].to_numpy()
                label = np.expand_dims(label, axis=0)
                if(type(Y) == type(None)): Y = label
                else: Y = np.concatenate( [Y, label ], axis=0 )

    print(f"{p_num} done| {ids}")
    return np.array(X),np.array(Y),freq

def get_accuracy(X,y):
    result = []
    traits = ["h","e","x","a","c","o"]
    for index,label in enumerate(traits):
        y = Y[:,index]
        X_copy = X.copy()
        X_copy = normalize(X_copy,axis=0)
        mnb = GaussianNB()
        mnb.fit(X_copy, y)
        acc = sum(mnb.predict(X_copy) == y) / len(y)
        scores = cross_val_score(mnb, X_copy, y)
        result.append([acc,scores.mean(),scores.std()])
        print(label,"| Accuracy: %0.2f Scores: %0.2f (+/- %0.2f)" % (acc,scores.mean(), scores.std() * 2))
    return result

# %%
try:
    # [33,2,10,12,16]
    t_out = 300
    pool = Pool()
    ids = np.array(list(EEG_image.keys()))
    p1 = pool.apply_async(build_data, [1,EEG_image,ids[0::6]])
    p2 = pool.apply_async(build_data, [2,EEG_image,ids[1::6]])
    p3 = pool.apply_async(build_data, [3,EEG_image,ids[2::6]])
    p4 = pool.apply_async(build_data, [4,EEG_image,ids[3::6]])
    p5 = pool.apply_async(build_data, [5,EEG_image,ids[4::6]])
    p6 = pool.apply_async(build_data, [6,EEG_image,ids[5::6]])
    ans1 = p1.get(timeout=t_out)
    ans2 = p2.get(timeout=t_out)
    ans3 = p3.get(timeout=t_out)
    ans4 = p4.get(timeout=t_out)
    ans5 = p5.get(timeout=t_out)
    ans6 = p6.get(timeout=t_out)
    X = np.concatenate([ans1[0] , ans2[0], ans3[0], ans4[0] ,ans5[0], ans6[0]])
    Y = np.concatenate([ans1[1] , ans2[1], ans3[1], ans4[1] ,ans5[1], ans6[1]])
    freq = ans1[2]
    print(X.shape, Y.shape)
finally:
    print("========= close ========")
    pool.close() 
    pool.terminate()
# Out:
# p_no=1|index=0|id=10
# p_no=2|index=0|id=12
# p_no=3|index=0|id=13
# p_no=4|index=0|id=14
# p_no=5|index=0|id=15
# p_no=6|index=0|id=16
# Computing rank from data with rank=None
#     Using tolerance 6.7e-06 (2.2e-16 eps * 8 dim * 3.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.2e-06 (2.2e-16 eps * 8 dim * 2.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.9e-06 (2.2e-16 eps * 8 dim * 1.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.5e-06 (2.2e-16 eps * 8 dim * 3.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.7e-06 (2.2e-16 eps * 8 dim * 3.2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=1|index=1|id=17
# Computing rank from data with rank=None
# Computing rank from data with rank=None
#     Using tolerance 2.5e-06 (2.2e-16 eps * 8 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
#     Using tolerance 6e-06 (2.2e-16 eps * 8 dim * 3.4e+09  max singular value)
# Estimating covariance using EMPIRICAL
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Done.
# Reducing data rank from 8 -> 8
# Computing rank from data with rank=None
#     Using tolerance 3.7e-06 (2.2e-16 eps * 8 dim * 2.1e+09  max singular value)
#     Estimated rank (mag): 8
# Estimating covariance using EMPIRICAL
# Done.
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Computing rank from data with rank=None
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
#     Using tolerance 2.3e-06 (2.2e-16 eps * 8 dim * 1.3e+09  max singular value)
# Computing rank from data with rank=None
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7e-06 (2.2e-16 eps * 8 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 8
#     Using tolerance 2e-06 (2.2e-16 eps * 8 dim * 1.1e+09  max singular value)
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Estimated rank (mag): 8
# Reducing data rank from 8 -> 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Estimating covariance using EMPIRICAL
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Done.
# Computing rank from data with rank=None
# Computing rank from data with rank=None
#     Using tolerance 3.2e-06 (2.2e-16 eps * 8 dim * 1.8e+09  max singular value)
#     Using tolerance 4.4e-06 (2.2e-16 eps * 8 dim * 2.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Estimated rank (mag): 8
# Reducing data rank from 8 -> 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Estimating covariance using EMPIRICAL
# Reducing data rank from 8 -> 8
# Done.
# Estimating covariance using EMPIRICAL
# Computing rank from data with rank=None
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.8e-06 (2.2e-16 eps * 8 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 8
#     Using tolerance 3.7e-06 (2.2e-16 eps * 8 dim * 2.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=3|index=1|id=2p_no=2|index=1|id=18
#
# Computing rank from data with rank=None
#     Using tolerance 7e-06 (2.2e-16 eps * 8 dim * 3.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-05 (2.2e-16 eps * 8 dim * 7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1e-06 (2.2e-16 eps * 8 dim * 2.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.7e-06 (2.2e-16 eps * 8 dim * 3.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
# Computing rank from data with rank=None
#     Using tolerance 1.4e-05 (2.2e-16 eps * 8 dim * 8.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
#     Using tolerance 8.8e-06 (2.2e-16 eps * 8 dim * 4.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.3e-06 (2.2e-16 eps * 8 dim * 4.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.4e-06 (2.2e-16 eps * 8 dim * 5.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-05 (2.2e-16 eps * 8 dim * 5.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# p_no=6|index=1|id=22Done.
#
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 8 dim * 6.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4e-06 (2.2e-16 eps * 8 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# p_no=4|index=1|id=20Done.
#
# Computing rank from data with rank=None
#     Using tolerance 4.8e-06 (2.2e-16 eps * 8 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.5e-06 (2.2e-16 eps * 8 dim * 3.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.8e-06 (2.2e-16 eps * 8 dim * 2.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-05 (2.2e-16 eps * 8 dim * 1e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=5|index=1|id=21
# Computing rank from data with rank=None
#     Using tolerance 4.1e-06 (2.2e-16 eps * 8 dim * 2.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-06 (2.2e-16 eps * 8 dim * 3.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.2e-06 (2.2e-16 eps * 8 dim * 4.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.6e-06 (2.2e-16 eps * 8 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.9e-06 (2.2e-16 eps * 8 dim * 2.2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
# Computing rank from data with rank=None
#     Using tolerance 1.3e-05 (2.2e-16 eps * 8 dim * 7.6e+09  max singular value)
#     Estimated rank (mag): 8
# p_no=2|index=2|id=25
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Using tolerance 9.3e-06 (2.2e-16 eps * 8 dim * 5.2e+09  max singular value)
# Reducing data rank from 8 -> 8
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Done.
# Estimating covariance using EMPIRICAL
# Reducing data rank from 8 -> 8
# Computing rank from data with rank=None
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.5e-06 (2.2e-16 eps * 8 dim * 3.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
#     Using tolerance 7.5e-06 (2.2e-16 eps * 8 dim * 4.2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Estimating covariance using EMPIRICAL
# Reducing data rank from 8 -> 8
# Done.
# Estimating covariance using EMPIRICAL
# Computing rank from data with rank=None
# Computing rank from data with rank=None
#     Using tolerance 4.8e-06 (2.2e-16 eps * 8 dim * 2.7e+09  max singular value)
# Done.
#     Using tolerance 5.5e-06 (2.2e-16 eps * 8 dim * 3.1e+09  max singular value)
# Computing rank from data with rank=None
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Using tolerance 8.2e-06 (2.2e-16 eps * 8 dim * 4.6e+09  max singular value)
# Reducing data rank from 8 -> 8
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Estimating covariance using EMPIRICAL
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Computing rank from data with rank=None
# Done.
# Computing rank from data with rank=None
# Reducing data rank from 8 -> 8
#     Using tolerance 7.5e-06 (2.2e-16 eps * 8 dim * 4.2e+09  max singular value)
#     Using tolerance 4.2e-06 (2.2e-16 eps * 8 dim * 2.4e+09  max singular value)
# Estimating covariance using EMPIRICAL
# Done.
#     Estimated rank (mag): 8
# Computing rank from data with rank=None
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Using tolerance 8.6e-06 (2.2e-16 eps * 8 dim * 4.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
#     Estimated rank (mag): 8
# Computing rank from data with rank=None
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
# Estimating covariance using EMPIRICAL
# Done.
#     Using tolerance 7.1e-06 (2.2e-16 eps * 8 dim * 4e+09  max singular value)
#     Estimated rank (mag): 8
# Computing rank from data with rank=None
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-06 (2.2e-16 eps * 8 dim * 3.5e+09  max singular value)
#     Estimated rank (mag): 8
#     Using tolerance 7.3e-06 (2.2e-16 eps * 8 dim * 4.1e+09  max singular value)
#     Using tolerance 9.7e-06 (2.2e-16 eps * 8 dim * 5.5e+09  max singular value)
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Estimated rank (mag): 8
#     Estimated rank (mag): 8
# Reducing data rank from 8 -> 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Estimating covariance using EMPIRICAL
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Done.
# Computing rank from data with rank=None
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
#     Using tolerance 7.1e-06 (2.2e-16 eps * 8 dim * 4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Done.
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=6|index=2|id=29
# p_no=1|index=2|id=23
# p_no=3|index=2|id=26
# Computing rank from data with rank=None
#     Using tolerance 6.8e-06 (2.2e-16 eps * 8 dim * 3.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3e-05 (2.2e-16 eps * 8 dim * 7.3e+09  max singular value)
#     Estimated rank (mag): 8
# Computing rank from data with rank=None
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Using tolerance 4.8e-06 (2.2e-16 eps * 8 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Estimating covariance using EMPIRICAL
# Done.
# Done.
# Computing rank from data with rank=None
# Computing rank from data with rank=None
#     Using tolerance 1e-05 (2.2e-16 eps * 8 dim * 5.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Using tolerance 3.6e-06 (2.2e-16 eps * 8 dim * 2e+09  max singular value)
#     Estimated rank (mag): 8
# Reducing data rank from 8 -> 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Estimating covariance using EMPIRICAL
# Reducing data rank from 8 -> 8
# Done.
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
# Computing rank from data with rank=None
#     Using tolerance 1.5e-05 (2.2e-16 eps * 8 dim * 8.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Using tolerance 7.2e-06 (2.2e-16 eps * 8 dim * 4.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Estimating covariance using EMPIRICAL
# Done.
# Done.
# Computing rank from data with rank=None
# Computing rank from data with rank=None
#     Using tolerance 6.6e-06 (2.2e-16 eps * 8 dim * 3.7e+09  max singular value)
#     Estimated rank (mag): 8
#     Using tolerance 6.4e-06 (2.2e-16 eps * 8 dim * 3.6e+09  max singular value)
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
#     Estimated rank (mag): 8
# Estimating covariance using EMPIRICAL
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Done.
# Computing rank from data with rank=None
# Reducing data rank from 8 -> 8
#     Using tolerance 4.4e-06 (2.2e-16 eps * 8 dim * 2.5e+09  max singular value)
# Estimating covariance using EMPIRICAL
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Done.
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=4|index=2|id=27p_no=5|index=2|id=28
#
# Computing rank from data with rank=None
#     Using tolerance 8.1e-06 (2.2e-16 eps * 8 dim * 4.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.1e-06 (2.2e-16 eps * 8 dim * 4.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.4e-06 (2.2e-16 eps * 8 dim * 3.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.9e-06 (2.2e-16 eps * 8 dim * 5e+09  max singular value)
# Computing rank from data with rank=None
#     Estimated rank (mag): 8
#     Using tolerance 8.1e-06 (2.2e-16 eps * 8 dim * 4.5e+09  max singular value)
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
#     Estimated rank (mag): 8
# Computing rank from data with rank=None
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
#     Using tolerance 9.9e-06 (2.2e-16 eps * 8 dim * 5.6e+09  max singular value)
# Done.
#     Estimated rank (mag): 8
# Computing rank from data with rank=None
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
#     Using tolerance 7.6e-06 (2.2e-16 eps * 8 dim * 4.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.8e-06 (2.2e-16 eps * 8 dim * 4.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
# Computing rank from data with rank=None
# Computing rank from data with rank=None
#     Using tolerance 7.9e-06 (2.2e-16 eps * 8 dim * 4.5e+09  max singular value)
#     Using tolerance 6.6e-06 (2.2e-16 eps * 8 dim * 3.7e+09  max singular value)
#     Using tolerance 6.1e-06 (2.2e-16 eps * 8 dim * 3.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Computing rank from data with rank=None
# Reducing data rank from 8 -> 8
# Computing rank from data with rank=None
#     Using tolerance 9.1e-06 (2.2e-16 eps * 8 dim * 5.1e+09  max singular value)
#     Estimated rank (mag): 8
# Estimating covariance using EMPIRICAL
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9e-06 (2.2e-16 eps * 8 dim * 5.1e+09  max singular value)
# Estimating covariance using EMPIRICAL
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Done.
#     Using tolerance 7.1e-06 (2.2e-16 eps * 8 dim * 4e+09  max singular value)
#     Estimated rank (mag): 8
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Done.
# Computing rank from data with rank=None
# Reducing data rank from 8 -> 8
# p_no=2|index=3|id=30
#     Using tolerance 9e-06 (2.2e-16 eps * 8 dim * 5.1e+09  max singular value)
# Estimating covariance using EMPIRICAL
# Done.
#     Estimated rank (mag): 8
# Computing rank from data with rank=None
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Using tolerance 8.6e-06 (2.2e-16 eps * 8 dim * 4.8e+09  max singular value)
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
#     Using tolerance 6.8e-06 (2.2e-16 eps * 8 dim * 3.8e+09  max singular value)
#     Estimated rank (mag): 8
# Done.
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Computing rank from data with rank=None
# Reducing data rank from 8 -> 8
#     Using tolerance 8.9e-06 (2.2e-16 eps * 8 dim * 5e+09  max singular value)
# Estimating covariance using EMPIRICAL
# Done.
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Computing rank from data with rank=None
#     Using tolerance 5.4e-06 (2.2e-16 eps * 8 dim * 3.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
# p_no=6|index=3|id=34
#     Using tolerance 6.1e-06 (2.2e-16 eps * 8 dim * 3.5e+09  max singular value)
#     Estimated rank (mag): 8
# Reducing data rank from 8 -> 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Estimating covariance using EMPIRICAL
# Done.
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=1|index=3|id=3
# p_no=4|index=3|id=32
# Computing rank from data with rank=None
#     Using tolerance 1.4e-05 (2.2e-16 eps * 8 dim * 7.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Computing rank from data with rank=None
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 8 dim * 6.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
#     Using tolerance 9.6e-06 (2.2e-16 eps * 8 dim * 5.4e+09  max singular value)
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
#     Using tolerance 1e-05 (2.2e-16 eps * 8 dim * 5.8e+09  max singular value)
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 8 dim * 6.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Using tolerance 9.8e-06 (2.2e-16 eps * 8 dim * 5.5e+09  max singular value)
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Computing rank from data with rank=None
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 8 dim * 6.1e+09  max singular value)
#     Using tolerance 1.1e-05 (2.2e-16 eps * 8 dim * 6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.8e-06 (2.2e-16 eps * 8 dim * 5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 8 dim * 6.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=3|index=3|id=31
# p_no=5|index=3|id=33
# Computing rank from data with rank=None
#     Using tolerance 1.2e-05 (2.2e-16 eps * 8 dim * 6.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7e-06 (2.2e-16 eps * 8 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3e-05 (2.2e-16 eps * 8 dim * 7.2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.4e-05 (2.2e-16 eps * 8 dim * 7.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-05 (2.2e-16 eps * 8 dim * 6.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=6|index=4|id=9
# Computing rank from data with rank=None
#     Using tolerance 7.1e-06 (2.2e-16 eps * 8 dim * 4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
# Computing rank from data with rank=None
#     Using tolerance 1.5e-05 (2.2e-16 eps * 8 dim * 8.2e+09  max singular value)
#     Using tolerance 7e-06 (2.2e-16 eps * 8 dim * 3.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Estimated rank (mag): 8
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Done.
# Computing rank from data with rank=None
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.8e-05 (2.2e-16 eps * 8 dim * 1e+10  max singular value)
#     Estimated rank (mag): 8
#     Using tolerance 7.4e-06 (2.2e-16 eps * 8 dim * 4.2e+09  max singular value)
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Done.
# Computing rank from data with rank=None
# Estimating covariance using EMPIRICAL
# Done.
#     Using tolerance 1.1e-05 (2.2e-16 eps * 8 dim * 6.1e+09  max singular value)
#     Estimated rank (mag): 8
# Computing rank from data with rank=None
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
#     Using tolerance 5.6e-06 (2.2e-16 eps * 8 dim * 3.2e+09  max singular value)
# Estimating covariance using EMPIRICAL
#     Estimated rank (mag): 8
# Done.
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Computing rank from data with rank=None
#     Using tolerance 1.7e-05 (2.2e-16 eps * 8 dim * 9.4e+09  max singular value)
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Computing rank from data with rank=None
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.9e-06 (2.2e-16 eps * 8 dim * 4.5e+09  max singular value)
#     Using tolerance 1.6e-05 (2.2e-16 eps * 8 dim * 8.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Estimated rank (mag): 8
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Done.
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7e-06 (2.2e-16 eps * 8 dim * 3.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.8e-06 (2.2e-16 eps * 8 dim * 4.9e+09  max singular value)
# p_no=1|index=4|id=35
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=4|index=4|id=7
# Computing rank from data with rank=None
#     Using tolerance 7.2e-06 (2.2e-16 eps * 8 dim * 4.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.4e-06 (2.2e-16 eps * 8 dim * 3.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.3e-06 (2.2e-16 eps * 8 dim * 4.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Computing rank from data with rank=None
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
#     Using tolerance 1.1e-05 (2.2e-16 eps * 8 dim * 6.2e+09  max singular value)
# Done.
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.3e-06 (2.2e-16 eps * 8 dim * 5.2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9e-06 (2.2e-16 eps * 8 dim * 5.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# p_no=2|index=4|id=5Estimating covariance using EMPIRICAL
# Done.
#
# Computing rank from data with rank=None
#     Using tolerance 5.4e-06 (2.2e-16 eps * 8 dim * 3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.4e-05 (2.2e-16 eps * 8 dim * 1.3e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.8e-06 (2.2e-16 eps * 8 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 8
# p_no=3|index=4|id=6    MAG: rank 8 computed from 8 data channels with 0 projectors
#
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.7e-06 (2.2e-16 eps * 8 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.8e-06 (2.2e-16 eps * 8 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4e-06 (2.2e-16 eps * 8 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.9e-06 (2.2e-16 eps * 8 dim * 1.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=5|index=4|id=8
# Computing rank from data with rank=None
#     Using tolerance 0.00015 (2.2e-16 eps * 8 dim * 8.5e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.4e-05 (2.2e-16 eps * 8 dim * 1.4e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.1e-05 (2.2e-16 eps * 8 dim * 2.9e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.5e-05 (2.2e-16 eps * 8 dim * 4.8e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2e-05 (2.2e-16 eps * 8 dim * 1.1e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# 6 done| [16 22 29 34  9]
# Computing rank from data with rank=None
#     Using tolerance 4e-06 (2.2e-16 eps * 8 dim * 2.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.9e-06 (2.2e-16 eps * 8 dim * 3.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.7e-06 (2.2e-16 eps * 8 dim * 2.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.3e-06 (2.2e-16 eps * 8 dim * 3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.5e-06 (2.2e-16 eps * 8 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.6e-06 (2.2e-16 eps * 8 dim * 2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.8e-06 (2.2e-16 eps * 8 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.4e-06 (2.2e-16 eps * 8 dim * 2.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# 4 done| [14 20 27 32  7]Reducing data rank from 8 -> 8
#
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7e-06 (2.2e-16 eps * 8 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.6e-06 (2.2e-16 eps * 8 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# 1 done| [10 17 23  3 35]
# Computing rank from data with rank=None
#     Using tolerance 4.9e-06 (2.2e-16 eps * 8 dim * 2.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Computing rank from data with rank=None
#     Using tolerance 6e-06 (2.2e-16 eps * 8 dim * 3.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Estimating covariance using EMPIRICAL
# Reducing data rank from 8 -> 8
# Done.
# Estimating covariance using EMPIRICAL
# Computing rank from data with rank=None
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.6e-06 (2.2e-16 eps * 8 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.6e-06 (2.2e-16 eps * 8 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 8
#     Using tolerance 3.8e-06 (2.2e-16 eps * 8 dim * 2.1e+09  max singular value)
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Estimating covariance using EMPIRICAL
# Done.
# Done.
# Computing rank from data with rank=None
# Computing rank from data with rank=None
#     Using tolerance 4.1e-06 (2.2e-16 eps * 8 dim * 2.3e+09  max singular value)
#     Using tolerance 4.3e-06 (2.2e-16 eps * 8 dim * 2.4e+09  max singular value)
#     Estimated rank (mag): 8
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Reducing data rank from 8 -> 8
# Computing rank from data with rank=None
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.9e-06 (2.2e-16 eps * 8 dim * 1.6e+09  max singular value)
#     Using tolerance 7.8e-06 (2.2e-16 eps * 8 dim * 4.4e+09  max singular value)
#     Estimated rank (mag): 8
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3e-06 (2.2e-16 eps * 8 dim * 1.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# 2 done| [12 18 25 30  5]
# 3 done| [13  2 26 31  6]Computing rank from data with rank=None
#
#     Using tolerance 6.7e-06 (2.2e-16 eps * 8 dim * 3.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8e-06 (2.2e-16 eps * 8 dim * 4.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.6e-06 (2.2e-16 eps * 8 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.9e-06 (2.2e-16 eps * 8 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5e-06 (2.2e-16 eps * 8 dim * 2.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# 5 done| [15 21 28 33  8]
# (1500, 8, 65) (1500, 6)
# ========= close ========

# %%
X,Y = shuffle(X,Y)
bands = []
for filt in filter_list:
    pt = np.argwhere((freq >= filt[0]) & (freq <= filt[1])).reshape(-1)
    bands.append(pt)
bands = np.array(bands)

result_image = []
best_image = 0
best_image_idx = -1
best_image_comb = None
for r in [1,2,3,4,5]:
    print("="*20,f"Number {r}","="*20)
    for comb in combinations([0,1,2,3,4],r):
        print(" ",band_names[list(comb)])
        selected_x = None
        # print(bands[ list(comb) ])
        for pt in bands[ list(comb) ]:
            # print(pt)
            if(type(selected_x) == type(None)): selected_x = X[:,:,pt].mean(axis=2)
            else:
                selected_x = np.concatenate([selected_x, X[:,:,pt].mean(axis=2)], axis=1)
        # print(selected_x.shape)
        # pts = np.concatenate( bands[ list(comb) ] )
        result = np.array(get_accuracy(selected_x,Y))
        print(" Averag accuracy:", result[:,0].mean(), "Average Score:", result[:,1].mean(), "Average Variance:", result[:,2].mean())
        result_image.append(result)
        if(result[:,1].mean() > best_image):
            best_image = result[:,1].mean()
            best_image_idx = len(result_image)-1
            best_image_comb = band_names[ list(comb) ]

print(f"Best Score is {best_image} at index {best_image_idx} with combination {best_image_comb}")
# Out:
# /tmp/ipykernel_110312/1983967163.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   bands = np.array(bands)
# ==================== Number 1 ====================
#   ['Delta']
# h | Accuracy: 0.56 Scores: 0.56 (+/- 0.05)
# e | Accuracy: 0.62 Scores: 0.62 (+/- 0.03)
# x | Accuracy: 0.62 Scores: 0.61 (+/- 0.04)
# a | Accuracy: 0.58 Scores: 0.59 (+/- 0.06)
# c | Accuracy: 0.63 Scores: 0.63 (+/- 0.04)
# o | Accuracy: 0.63 Scores: 0.63 (+/- 0.03)
#  Averag accuracy: 0.6077777777777778 Average Score: 0.6065555555555556 Average Variance: 0.020408074068726672
#   ['Theta']
# h | Accuracy: 0.64 Scores: 0.64 (+/- 0.07)
# e | Accuracy: 0.66 Scores: 0.66 (+/- 0.06)
# x | Accuracy: 0.65 Scores: 0.64 (+/- 0.06)
# a | Accuracy: 0.60 Scores: 0.59 (+/- 0.06)
# c | Accuracy: 0.64 Scores: 0.63 (+/- 0.06)
# o | Accuracy: 0.62 Scores: 0.63 (+/- 0.05)
#  Averag accuracy: 0.634888888888889 Average Score: 0.6312222222222222 Average Variance: 0.030095150110424882
#   ['Alpha']
# h | Accuracy: 0.64 Scores: 0.63 (+/- 0.07)
# e | Accuracy: 0.65 Scores: 0.64 (+/- 0.05)
# x | Accuracy: 0.67 Scores: 0.66 (+/- 0.03)
# a | Accuracy: 0.66 Scores: 0.65 (+/- 0.05)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.03)
# o | Accuracy: 0.63 Scores: 0.63 (+/- 0.06)
#  Averag accuracy: 0.6572222222222223 Average Score: 0.652 Average Variance: 0.02466526393834108
#   ['Beta']
# h | Accuracy: 0.68 Scores: 0.68 (+/- 0.05)
# e | Accuracy: 0.72 Scores: 0.72 (+/- 0.08)
# x | Accuracy: 0.72 Scores: 0.72 (+/- 0.03)
# a | Accuracy: 0.69 Scores: 0.68 (+/- 0.05)
# c | Accuracy: 0.66 Scores: 0.65 (+/- 0.04)
# o | Accuracy: 0.62 Scores: 0.62 (+/- 0.03)
#  Averag accuracy: 0.6822222222222223 Average Score: 0.6792222222222223 Average Variance: 0.023280541585529873
#   ['Gamma']
# h | Accuracy: 0.67 Scores: 0.67 (+/- 0.10)
# e | Accuracy: 0.60 Scores: 0.60 (+/- 0.08)
# x | Accuracy: 0.66 Scores: 0.65 (+/- 0.02)
# a | Accuracy: 0.74 Scores: 0.72 (+/- 0.03)
# c | Accuracy: 0.63 Scores: 0.63 (+/- 0.04)
# o | Accuracy: 0.57 Scores: 0.57 (+/- 0.08)
#  Averag accuracy: 0.6444444444444445 Average Score: 0.6404444444444445 Average Variance: 0.02865203536106695
# ==================== Number 2 ====================
#   ['Delta' 'Theta']
# h | Accuracy: 0.61 Scores: 0.60 (+/- 0.07)
# e | Accuracy: 0.66 Scores: 0.66 (+/- 0.06)
# x | Accuracy: 0.64 Scores: 0.63 (+/- 0.05)
# a | Accuracy: 0.60 Scores: 0.60 (+/- 0.07)
# c | Accuracy: 0.64 Scores: 0.64 (+/- 0.07)
# o | Accuracy: 0.65 Scores: 0.66 (+/- 0.04)
#  Averag accuracy: 0.6352222222222221 Average Score: 0.6307777777777777 Average Variance: 0.03037212124773617
#   ['Delta' 'Alpha']
# h | Accuracy: 0.62 Scores: 0.61 (+/- 0.09)
# e | Accuracy: 0.65 Scores: 0.64 (+/- 0.05)
# x | Accuracy: 0.65 Scores: 0.65 (+/- 0.04)
# a | Accuracy: 0.67 Scores: 0.66 (+/- 0.05)
# c | Accuracy: 0.68 Scores: 0.68 (+/- 0.06)
# o | Accuracy: 0.66 Scores: 0.65 (+/- 0.03)
#  Averag accuracy: 0.6539999999999999 Average Score: 0.6493333333333333 Average Variance: 0.027484431763552735
#   ['Delta' 'Beta']
# h | Accuracy: 0.67 Scores: 0.66 (+/- 0.07)
# e | Accuracy: 0.67 Scores: 0.67 (+/- 0.04)
# x | Accuracy: 0.70 Scores: 0.70 (+/- 0.06)
# a | Accuracy: 0.69 Scores: 0.68 (+/- 0.05)
# c | Accuracy: 0.67 Scores: 0.66 (+/- 0.05)
# o | Accuracy: 0.66 Scores: 0.64 (+/- 0.06)
#  Averag accuracy: 0.6771111111111111 Average Score: 0.6674444444444445 Average Variance: 0.027637700813644455
#   ['Delta' 'Gamma']
# h | Accuracy: 0.74 Scores: 0.73 (+/- 0.07)
# e | Accuracy: 0.63 Scores: 0.63 (+/- 0.07)
# x | Accuracy: 0.65 Scores: 0.65 (+/- 0.05)
# a | Accuracy: 0.64 Scores: 0.63 (+/- 0.05)
# c | Accuracy: 0.66 Scores: 0.67 (+/- 0.03)
# o | Accuracy: 0.65 Scores: 0.65 (+/- 0.04)
#  Averag accuracy: 0.6624444444444445 Average Score: 0.6597777777777777 Average Variance: 0.026044065510498714
#   ['Theta' 'Alpha']
# h | Accuracy: 0.67 Scores: 0.65 (+/- 0.08)
# e | Accuracy: 0.68 Scores: 0.67 (+/- 0.06)
# x | Accuracy: 0.67 Scores: 0.67 (+/- 0.03)
# a | Accuracy: 0.66 Scores: 0.65 (+/- 0.06)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.05)
# o | Accuracy: 0.65 Scores: 0.64 (+/- 0.06)
#  Averag accuracy: 0.6711111111111111 Average Score: 0.6637777777777778 Average Variance: 0.028568620425900717
#   ['Theta' 'Beta']
# h | Accuracy: 0.68 Scores: 0.68 (+/- 0.05)
# e | Accuracy: 0.69 Scores: 0.69 (+/- 0.06)
# x | Accuracy: 0.71 Scores: 0.70 (+/- 0.05)
# a | Accuracy: 0.67 Scores: 0.67 (+/- 0.05)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.06)
# o | Accuracy: 0.63 Scores: 0.62 (+/- 0.05)
#  Averag accuracy: 0.6786666666666666 Average Score: 0.6747777777777778 Average Variance: 0.02654687915602566
#   ['Theta' 'Gamma']
# h | Accuracy: 0.76 Scores: 0.74 (+/- 0.09)
# e | Accuracy: 0.66 Scores: 0.66 (+/- 0.07)
# x | Accuracy: 0.66 Scores: 0.65 (+/- 0.03)
# a | Accuracy: 0.67 Scores: 0.65 (+/- 0.06)
# c | Accuracy: 0.65 Scores: 0.65 (+/- 0.03)
# o | Accuracy: 0.62 Scores: 0.61 (+/- 0.05)
#  Averag accuracy: 0.6715555555555556 Average Score: 0.6616666666666667 Average Variance: 0.02760951751380597
#   ['Alpha' 'Beta']
# h | Accuracy: 0.68 Scores: 0.66 (+/- 0.07)
# e | Accuracy: 0.72 Scores: 0.71 (+/- 0.05)
# x | Accuracy: 0.72 Scores: 0.72 (+/- 0.03)
# a | Accuracy: 0.71 Scores: 0.70 (+/- 0.07)
# c | Accuracy: 0.71 Scores: 0.71 (+/- 0.06)
# o | Accuracy: 0.65 Scores: 0.64 (+/- 0.06)
#  Averag accuracy: 0.6968888888888888 Average Score: 0.6903333333333332 Average Variance: 0.028064829364298466
#   ['Alpha' 'Gamma']
# h | Accuracy: 0.75 Scores: 0.74 (+/- 0.06)
# e | Accuracy: 0.65 Scores: 0.65 (+/- 0.08)
# x | Accuracy: 0.69 Scores: 0.68 (+/- 0.02)
# a | Accuracy: 0.72 Scores: 0.71 (+/- 0.06)
# c | Accuracy: 0.68 Scores: 0.68 (+/- 0.04)
# o | Accuracy: 0.63 Scores: 0.63 (+/- 0.05)
#  Averag accuracy: 0.6864444444444443 Average Score: 0.682111111111111 Average Variance: 0.025460740419936612
#   ['Beta' 'Gamma']
# h | Accuracy: 0.76 Scores: 0.75 (+/- 0.11)
# e | Accuracy: 0.66 Scores: 0.66 (+/- 0.09)
# x | Accuracy: 0.74 Scores: 0.73 (+/- 0.03)
# a | Accuracy: 0.72 Scores: 0.71 (+/- 0.04)
# c | Accuracy: 0.63 Scores: 0.63 (+/- 0.03)
# o | Accuracy: 0.60 Scores: 0.60 (+/- 0.05)
#  Averag accuracy: 0.6866666666666666 Average Score: 0.6808888888888888 Average Variance: 0.02959989209924015
# ==================== Number 3 ====================
#   ['Delta' 'Theta' 'Alpha']
# h | Accuracy: 0.63 Scores: 0.62 (+/- 0.08)
# e | Accuracy: 0.67 Scores: 0.66 (+/- 0.07)
# x | Accuracy: 0.66 Scores: 0.65 (+/- 0.05)
# a | Accuracy: 0.65 Scores: 0.65 (+/- 0.05)
# c | Accuracy: 0.67 Scores: 0.67 (+/- 0.06)
# o | Accuracy: 0.66 Scores: 0.66 (+/- 0.06)
#  Averag accuracy: 0.6562222222222222 Average Score: 0.6532222222222223 Average Variance: 0.031023463538572566
#   ['Delta' 'Theta' 'Beta']
# h | Accuracy: 0.68 Scores: 0.66 (+/- 0.07)
# e | Accuracy: 0.67 Scores: 0.67 (+/- 0.06)
# x | Accuracy: 0.70 Scores: 0.69 (+/- 0.06)
# a | Accuracy: 0.67 Scores: 0.65 (+/- 0.05)
# c | Accuracy: 0.68 Scores: 0.68 (+/- 0.06)
# o | Accuracy: 0.65 Scores: 0.65 (+/- 0.07)
#  Averag accuracy: 0.6727777777777778 Average Score: 0.6653333333333332 Average Variance: 0.03051892879109841
#   ['Delta' 'Theta' 'Gamma']
# h | Accuracy: 0.73 Scores: 0.72 (+/- 0.05)
# e | Accuracy: 0.65 Scores: 0.66 (+/- 0.05)
# x | Accuracy: 0.64 Scores: 0.64 (+/- 0.05)
# a | Accuracy: 0.63 Scores: 0.62 (+/- 0.06)
# c | Accuracy: 0.66 Scores: 0.66 (+/- 0.04)
# o | Accuracy: 0.66 Scores: 0.65 (+/- 0.05)
#  Averag accuracy: 0.6632222222222223 Average Score: 0.6591111111111111 Average Variance: 0.025823074073352784
#   ['Delta' 'Alpha' 'Beta']
# h | Accuracy: 0.68 Scores: 0.66 (+/- 0.07)
# e | Accuracy: 0.67 Scores: 0.67 (+/- 0.04)
# x | Accuracy: 0.69 Scores: 0.69 (+/- 0.02)
# a | Accuracy: 0.70 Scores: 0.69 (+/- 0.06)
# c | Accuracy: 0.71 Scores: 0.70 (+/- 0.05)
# o | Accuracy: 0.66 Scores: 0.65 (+/- 0.06)
#  Averag accuracy: 0.6844444444444444 Average Score: 0.6766666666666666 Average Variance: 0.02611518834698841
#   ['Delta' 'Alpha' 'Gamma']
# h | Accuracy: 0.73 Scores: 0.71 (+/- 0.07)
# e | Accuracy: 0.65 Scores: 0.65 (+/- 0.06)
# x | Accuracy: 0.66 Scores: 0.66 (+/- 0.03)
# a | Accuracy: 0.70 Scores: 0.69 (+/- 0.04)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.03)
# o | Accuracy: 0.66 Scores: 0.66 (+/- 0.04)
#  Averag accuracy: 0.6825555555555556 Average Score: 0.676888888888889 Average Variance: 0.023673925371748446
#   ['Delta' 'Beta' 'Gamma']
# h | Accuracy: 0.76 Scores: 0.75 (+/- 0.06)
# e | Accuracy: 0.67 Scores: 0.67 (+/- 0.07)
# x | Accuracy: 0.71 Scores: 0.70 (+/- 0.06)
# a | Accuracy: 0.70 Scores: 0.70 (+/- 0.06)
# c | Accuracy: 0.65 Scores: 0.64 (+/- 0.03)
# o | Accuracy: 0.64 Scores: 0.64 (+/- 0.06)
#  Averag accuracy: 0.6874444444444444 Average Score: 0.6841111111111111 Average Variance: 0.028283895923299645
#   ['Theta' 'Alpha' 'Beta']
# h | Accuracy: 0.69 Scores: 0.67 (+/- 0.06)
# e | Accuracy: 0.70 Scores: 0.69 (+/- 0.06)
# x | Accuracy: 0.69 Scores: 0.69 (+/- 0.04)
# a | Accuracy: 0.69 Scores: 0.69 (+/- 0.07)
# c | Accuracy: 0.71 Scores: 0.71 (+/- 0.05)
# o | Accuracy: 0.65 Scores: 0.65 (+/- 0.05)
#  Averag accuracy: 0.6865555555555556 Average Score: 0.6830000000000002 Average Variance: 0.0269161262208281
#   ['Theta' 'Alpha' 'Gamma']
# h | Accuracy: 0.75 Scores: 0.73 (+/- 0.07)
# e | Accuracy: 0.68 Scores: 0.68 (+/- 0.06)
# x | Accuracy: 0.66 Scores: 0.65 (+/- 0.03)
# a | Accuracy: 0.69 Scores: 0.70 (+/- 0.06)
# c | Accuracy: 0.70 Scores: 0.70 (+/- 0.04)
# o | Accuracy: 0.65 Scores: 0.64 (+/- 0.04)
#  Averag accuracy: 0.691 Average Score: 0.6832222222222222 Average Variance: 0.025322687869744263
#   ['Theta' 'Beta' 'Gamma']
# h | Accuracy: 0.76 Scores: 0.75 (+/- 0.09)
# e | Accuracy: 0.69 Scores: 0.68 (+/- 0.08)
# x | Accuracy: 0.72 Scores: 0.71 (+/- 0.03)
# a | Accuracy: 0.70 Scores: 0.69 (+/- 0.04)
# c | Accuracy: 0.65 Scores: 0.65 (+/- 0.03)
# o | Accuracy: 0.62 Scores: 0.60 (+/- 0.06)
#  Averag accuracy: 0.6893333333333334 Average Score: 0.6815555555555556 Average Variance: 0.026803606223006107
#   ['Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.74 Scores: 0.74 (+/- 0.07)
# e | Accuracy: 0.69 Scores: 0.69 (+/- 0.08)
# x | Accuracy: 0.73 Scores: 0.72 (+/- 0.03)
# a | Accuracy: 0.72 Scores: 0.72 (+/- 0.06)
# c | Accuracy: 0.68 Scores: 0.68 (+/- 0.03)
# o | Accuracy: 0.63 Scores: 0.62 (+/- 0.05)
#  Averag accuracy: 0.6996666666666668 Average Score: 0.6944444444444443 Average Variance: 0.02592720854451572
# ==================== Number 4 ====================
#   ['Delta' 'Theta' 'Alpha' 'Beta']
# h | Accuracy: 0.68 Scores: 0.66 (+/- 0.07)
# e | Accuracy: 0.67 Scores: 0.67 (+/- 0.07)
# x | Accuracy: 0.69 Scores: 0.69 (+/- 0.03)
# a | Accuracy: 0.68 Scores: 0.68 (+/- 0.07)
# c | Accuracy: 0.70 Scores: 0.70 (+/- 0.06)
# o | Accuracy: 0.66 Scores: 0.65 (+/- 0.06)
#  Averag accuracy: 0.6807777777777778 Average Score: 0.6749999999999999 Average Variance: 0.028845089577765572
#   ['Delta' 'Theta' 'Alpha' 'Gamma']
# h | Accuracy: 0.72 Scores: 0.70 (+/- 0.07)
# e | Accuracy: 0.66 Scores: 0.65 (+/- 0.06)
# x | Accuracy: 0.66 Scores: 0.65 (+/- 0.04)
# a | Accuracy: 0.68 Scores: 0.67 (+/- 0.05)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.05)
# o | Accuracy: 0.66 Scores: 0.66 (+/- 0.05)
#  Averag accuracy: 0.6782222222222223 Average Score: 0.6705555555555556 Average Variance: 0.02645965413163309
#   ['Delta' 'Theta' 'Beta' 'Gamma']
# h | Accuracy: 0.75 Scores: 0.73 (+/- 0.08)
# e | Accuracy: 0.67 Scores: 0.67 (+/- 0.06)
# x | Accuracy: 0.71 Scores: 0.70 (+/- 0.06)
# a | Accuracy: 0.68 Scores: 0.67 (+/- 0.06)
# c | Accuracy: 0.66 Scores: 0.66 (+/- 0.04)
# o | Accuracy: 0.65 Scores: 0.64 (+/- 0.05)
#  Averag accuracy: 0.6848888888888888 Average Score: 0.6801111111111111 Average Variance: 0.02950780946770347
#   ['Delta' 'Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.74 Scores: 0.73 (+/- 0.08)
# e | Accuracy: 0.68 Scores: 0.68 (+/- 0.06)
# x | Accuracy: 0.71 Scores: 0.70 (+/- 0.03)
# a | Accuracy: 0.73 Scores: 0.72 (+/- 0.04)
# c | Accuracy: 0.68 Scores: 0.68 (+/- 0.04)
# o | Accuracy: 0.65 Scores: 0.65 (+/- 0.07)
#  Averag accuracy: 0.6992222222222222 Average Score: 0.6932222222222221 Average Variance: 0.027473401140509158
#   ['Theta' 'Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.74 Scores: 0.73 (+/- 0.07)
# e | Accuracy: 0.69 Scores: 0.69 (+/- 0.06)
# x | Accuracy: 0.71 Scores: 0.70 (+/- 0.04)
# a | Accuracy: 0.71 Scores: 0.69 (+/- 0.06)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.05)
# o | Accuracy: 0.64 Scores: 0.63 (+/- 0.05)
#  Averag accuracy: 0.6961111111111111 Average Score: 0.6901111111111112 Average Variance: 0.02681533292462086
# ==================== Number 5 ====================
#   ['Delta' 'Theta' 'Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.73 Scores: 0.72 (+/- 0.08)
# e | Accuracy: 0.67 Scores: 0.67 (+/- 0.06)
# x | Accuracy: 0.69 Scores: 0.69 (+/- 0.03)
# a | Accuracy: 0.71 Scores: 0.70 (+/- 0.04)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.04)
# o | Accuracy: 0.65 Scores: 0.65 (+/- 0.05)
#  Averag accuracy: 0.6905555555555555 Average Score: 0.6881111111111111 Average Variance: 0.02525518291096747
# Best Score is 0.6944444444444443 at index 24 with combination ['Alpha' 'Beta' 'Gamma']

# %%
try:
    # [33,2,10,12,16]
    t_out = 300
    pool = Pool()
    ids = np.array(list(EEG_audio.keys()))
    p1 = pool.apply_async(build_data, [1,EEG_audio,ids[0::6]])
    p2 = pool.apply_async(build_data, [2,EEG_audio,ids[1::6]])
    p3 = pool.apply_async(build_data, [3,EEG_audio,ids[2::6]])
    p4 = pool.apply_async(build_data, [4,EEG_audio,ids[3::6]])
    p5 = pool.apply_async(build_data, [5,EEG_audio,ids[4::6]])
    p6 = pool.apply_async(build_data, [6,EEG_audio,ids[5::6]])
    ans1 = p1.get(timeout=t_out)
    ans2 = p2.get(timeout=t_out)
    ans3 = p3.get(timeout=t_out)
    ans4 = p4.get(timeout=t_out)
    ans5 = p5.get(timeout=t_out)
    ans6 = p6.get(timeout=t_out)
    X = np.concatenate([ans1[0] , ans2[0], ans3[0], ans4[0] ,ans5[0], ans6[0]])
    Y = np.concatenate([ans1[1] , ans2[1], ans3[1], ans4[1] ,ans5[1], ans6[1]])
    freq = ans1[2]
    print(X.shape, Y.shape)
finally:
    print("========= close ========")
    pool.close() 
    pool.terminate()
# Out:
# p_no=1|index=0|id=10
# p_no=2|index=0|id=12
# p_no=3|index=0|id=13
# p_no=4|index=0|id=14
# p_no=5|index=0|id=15
# p_no=6|index=0|id=16
# Computing rank from data with rank=None
#     Using tolerance 8.6e-06 (2.2e-16 eps * 8 dim * 4.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.4e-06 (2.2e-16 eps * 8 dim * 2.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.6e-05 (2.2e-16 eps * 8 dim * 8.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2e-06 (2.2e-16 eps * 8 dim * 2.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9e-06 (2.2e-16 eps * 8 dim * 5.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=1|index=1|id=17
# Computing rank from data with rank=None
#     Using tolerance 3.1e-06 (2.2e-16 eps * 8 dim * 1.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.9e-06 (2.2e-16 eps * 8 dim * 3.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7e-06 (2.2e-16 eps * 8 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.1e-06 (2.2e-16 eps * 8 dim * 2.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.8e-06 (2.2e-16 eps * 8 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-05 (2.2e-16 eps * 8 dim * 5.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.8e-06 (2.2e-16 eps * 8 dim * 4.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.5e-06 (2.2e-16 eps * 8 dim * 4.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# p_no=2|index=1|id=18Estimating covariance using EMPIRICAL
#
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-06 (2.2e-16 eps * 8 dim * 5.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.5e-06 (2.2e-16 eps * 8 dim * 4.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=4|index=1|id=20
# Computing rank from data with rank=None
#     Using tolerance 2.9e-06 (2.2e-16 eps * 8 dim * 1.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.3e-06 (2.2e-16 eps * 8 dim * 3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.3e-06 (2.2e-16 eps * 8 dim * 3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-06 (2.2e-16 eps * 8 dim * 3.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.8e-06 (2.2e-16 eps * 8 dim * 4.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=3|index=1|id=2
# Computing rank from data with rank=None
#     Using tolerance 6.7e-06 (2.2e-16 eps * 8 dim * 3.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.3e-06 (2.2e-16 eps * 8 dim * 2.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4e-06 (2.2e-16 eps * 8 dim * 2.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.2e-06 (2.2e-16 eps * 8 dim * 2.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.9e-06 (2.2e-16 eps * 8 dim * 3.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7e-06 (2.2e-16 eps * 8 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# p_no=5|index=1|id=21
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.1e-06 (2.2e-16 eps * 8 dim * 3.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7e-06 (2.2e-16 eps * 8 dim * 3.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6e-06 (2.2e-16 eps * 8 dim * 4.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4e-06 (2.2e-16 eps * 8 dim * 2.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=6|index=1|id=22
# Computing rank from data with rank=None
#     Using tolerance 1.6e-05 (2.2e-16 eps * 8 dim * 9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-05 (2.2e-16 eps * 8 dim * 5.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 8 dim * 6.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-05 (2.2e-16 eps * 8 dim * 6.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9e-06 (2.2e-16 eps * 8 dim * 5.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=1|index=2|id=23
# Computing rank from data with rank=None
#     Using tolerance 5.6e-06 (2.2e-16 eps * 8 dim * 3.2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.9e-06 (2.2e-16 eps * 8 dim * 2.2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.5e-06 (2.2e-16 eps * 8 dim * 3.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.5e-06 (2.2e-16 eps * 8 dim * 2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-06 (2.2e-16 eps * 8 dim * 3.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=4|index=2|id=27
# Computing rank from data with rank=None
#     Using tolerance 4.6e-06 (2.2e-16 eps * 8 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-05 (2.2e-16 eps * 8 dim * 5.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.1e-06 (2.2e-16 eps * 8 dim * 3.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-06 (2.2e-16 eps * 8 dim * 3.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.2e-06 (2.2e-16 eps * 8 dim * 2.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.5e-06 (2.2e-16 eps * 8 dim * 3.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.5e-06 (2.2e-16 eps * 8 dim * 4.2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# p_no=2|index=2|id=25
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-05 (2.2e-16 eps * 8 dim * 6.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 8 dim * 6.2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.4e-06 (2.2e-16 eps * 8 dim * 4.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=3|index=2|id=26
# Computing rank from data with rank=None
#     Using tolerance 1e-05 (2.2e-16 eps * 8 dim * 5.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.3e-06 (2.2e-16 eps * 8 dim * 3.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.9e-06 (2.2e-16 eps * 8 dim * 5.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-05 (2.2e-16 eps * 8 dim * 6.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.9e-05 (2.2e-16 eps * 8 dim * 3.3e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.5e-06 (2.2e-16 eps * 8 dim * 1.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1e-06 (2.2e-16 eps * 8 dim * 2.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=5|index=2|id=28Computing rank from data with rank=None
#
#     Using tolerance 3.6e-06 (2.2e-16 eps * 8 dim * 2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-06 (2.2e-16 eps * 8 dim * 3.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.7e-06 (2.2e-16 eps * 8 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=6|index=2|id=29
# Computing rank from data with rank=None
#     Using tolerance 3.5e-06 (2.2e-16 eps * 8 dim * 2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.4e-06 (2.2e-16 eps * 8 dim * 3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.4e-06 (2.2e-16 eps * 8 dim * 2.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6e-06 (2.2e-16 eps * 8 dim * 3.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.9e-06 (2.2e-16 eps * 8 dim * 2.2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=1|index=3|id=3
# Computing rank from data with rank=None
#     Using tolerance 8.3e-06 (2.2e-16 eps * 8 dim * 4.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.2e-06 (2.2e-16 eps * 8 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.6e-06 (2.2e-16 eps * 8 dim * 4.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.8e-06 (2.2e-16 eps * 8 dim * 3.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.5e-06 (2.2e-16 eps * 8 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=4|index=3|id=32
# Computing rank from data with rank=None
#     Using tolerance 8.4e-06 (2.2e-16 eps * 8 dim * 4.8e+09  max singular value)
#     Estimated rank (mag): 8
# Computing rank from data with rank=None
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9e-06 (2.2e-16 eps * 8 dim * 5.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
#     Using tolerance 1.3e-05 (2.2e-16 eps * 8 dim * 7.3e+09  max singular value)
# Estimating covariance using EMPIRICAL
#     Estimated rank (mag): 8
# Done.
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Computing rank from data with rank=None
#     Using tolerance 5.6e-06 (2.2e-16 eps * 8 dim * 3.2e+09  max singular value)
#     Estimated rank (mag): 8
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Done.
# Computing rank from data with rank=None
# Reducing data rank from 8 -> 8
#     Using tolerance 9.5e-06 (2.2e-16 eps * 8 dim * 5.3e+09  max singular value)
# Estimating covariance using EMPIRICAL
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Done.
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
# Computing rank from data with rank=None
#     Using tolerance 1.2e-05 (2.2e-16 eps * 8 dim * 6.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-05 (2.2e-16 eps * 8 dim * 5.8e+09  max singular value)
#     Using tolerance 7.2e-06 (2.2e-16 eps * 8 dim * 4.1e+09  max singular value)
#     Estimated rank (mag): 8
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Reducing data rank from 8 -> 8
# Done.
# Estimating covariance using EMPIRICAL
# Computing rank from data with rank=None
# Done.
#     Using tolerance 7.8e-06 (2.2e-16 eps * 8 dim * 4.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-05 (2.2e-16 eps * 8 dim * 6.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=3|index=3|id=31p_no=2|index=3|id=30
#
# Computing rank from data with rank=None
#     Using tolerance 9.9e-06 (2.2e-16 eps * 8 dim * 5.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 8 dim * 6.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.8e-06 (2.2e-16 eps * 8 dim * 5.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-05 (2.2e-16 eps * 8 dim * 6.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.6e-06 (2.2e-16 eps * 8 dim * 5.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=6|index=3|id=34Computing rank from data with rank=None
#
#     Using tolerance 8.4e-06 (2.2e-16 eps * 8 dim * 4.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.4e-06 (2.2e-16 eps * 8 dim * 4.2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.3e-05 (2.2e-16 eps * 8 dim * 7.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.5e-05 (2.2e-16 eps * 8 dim * 8.2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.4e-05 (2.2e-16 eps * 8 dim * 8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=5|index=3|id=33
# Computing rank from data with rank=None
#     Using tolerance 2.1e-05 (2.2e-16 eps * 8 dim * 1.2e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2e-05 (2.2e-16 eps * 8 dim * 1.1e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.9e-05 (2.2e-16 eps * 8 dim * 1e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 8 dim * 5.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.2e-05 (2.2e-16 eps * 8 dim * 6.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=1|index=4|id=35
# Computing rank from data with rank=None
#     Using tolerance 9.6e-06 (2.2e-16 eps * 8 dim * 5.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.1e-05 (2.2e-16 eps * 8 dim * 6.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.1e-06 (2.2e-16 eps * 8 dim * 5.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 8.7e-06 (2.2e-16 eps * 8 dim * 4.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.9e-06 (2.2e-16 eps * 8 dim * 4.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=4|index=4|id=7
# Computing rank from data with rank=None
#     Using tolerance 7.2e-06 (2.2e-16 eps * 8 dim * 4.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.6e-06 (2.2e-16 eps * 8 dim * 3.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.8e-06 (2.2e-16 eps * 8 dim * 3.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.6e-06 (2.2e-16 eps * 8 dim * 3.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.1e-06 (2.2e-16 eps * 8 dim * 5.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.3e-05 (2.2e-16 eps * 8 dim * 1.3e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
# p_no=2|index=4|id=5
#     Using tolerance 1.4e-05 (2.2e-16 eps * 8 dim * 8.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 7.4e-06 (2.2e-16 eps * 8 dim * 4.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.9e-06 (2.2e-16 eps * 8 dim * 3.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.2e-06 (2.2e-16 eps * 8 dim * 3.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=3|index=4|id=6
# Computing rank from data with rank=None
#     Using tolerance 1e-05 (2.2e-16 eps * 8 dim * 5.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1.4e-05 (2.2e-16 eps * 8 dim * 7.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 1e-05 (2.2e-16 eps * 8 dim * 5.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.3e-06 (2.2e-16 eps * 8 dim * 5.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.6e-06 (2.2e-16 eps * 8 dim * 3.2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.7e-06 (2.2e-16 eps * 8 dim * 2.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
# p_no=6|index=4|id=9
#     Using tolerance 3.3e-06 (2.2e-16 eps * 8 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.4e-06 (2.2e-16 eps * 8 dim * 2.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 9.9e-06 (2.2e-16 eps * 8 dim * 5.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.6e-06 (2.2e-16 eps * 8 dim * 2.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# p_no=5|index=4|id=8
# Computing rank from data with rank=None
#     Using tolerance 4e-06 (2.2e-16 eps * 8 dim * 2.2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1e-06 (2.2e-16 eps * 8 dim * 2.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.1e-06 (2.2e-16 eps * 8 dim * 2.3e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.2e-06 (2.2e-16 eps * 8 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.2e-06 (2.2e-16 eps * 8 dim * 2.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.4e-06 (2.2e-16 eps * 8 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.2e-06 (2.2e-16 eps * 8 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.1e-06 (2.2e-16 eps * 8 dim * 1.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# 1 done| [10 17 23  3 35]
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.7e-06 (2.2e-16 eps * 8 dim * 1.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.3e-06 (2.2e-16 eps * 8 dim * 1.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# 4 done| [14 20 27 32  7]
# Computing rank from data with rank=None
#     Using tolerance 6.3e-06 (2.2e-16 eps * 8 dim * 3.5e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.8e-06 (2.2e-16 eps * 8 dim * 1.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.8e-06 (2.2e-16 eps * 8 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 2.1e-05 (2.2e-16 eps * 8 dim * 1.2e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.3e-06 (2.2e-16 eps * 8 dim * 3.6e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# 3 done| [13  2 26 31  6]
# Computing rank from data with rank=None
#     Using tolerance 4.3e-06 (2.2e-16 eps * 8 dim * 2.4e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.7e-06 (2.2e-16 eps * 8 dim * 2.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.8e-06 (2.2e-16 eps * 8 dim * 2.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.9e-06 (2.2e-16 eps * 8 dim * 2.2e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 4.8e-06 (2.2e-16 eps * 8 dim * 2.7e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Computing rank from data with rank=None
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
#     Using tolerance 3.8e-05 (2.2e-16 eps * 8 dim * 2.2e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Computing rank from data with rank=None
# Done.
# Computing rank from data with rank=None
#     Using tolerance 6.9e-06 (2.2e-16 eps * 8 dim * 3.9e+09  max singular value)
#     Estimated rank (mag): 8
#     Using tolerance 0.00015 (2.2e-16 eps * 8 dim * 8.4e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Reducing data rank from 8 -> 8
# Computing rank from data with rank=None
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 5.4e-06 (2.2e-16 eps * 8 dim * 3.1e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# 2 done| [12 18 25 30  5]    Using tolerance 5e-05 (2.2e-16 eps * 8 dim * 2.8e+10  max singular value)
#     Estimated rank (mag): 8
#
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Estimating covariance using EMPIRICAL
# Done.
# Done.
# Computing rank from data with rank=None
# Computing rank from data with rank=None
#     Using tolerance 5.6e-06 (2.2e-16 eps * 8 dim * 3.2e+09  max singular value)
#     Estimated rank (mag): 8
#     Using tolerance 5.1e-05 (2.2e-16 eps * 8 dim * 2.9e+10  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Estimating covariance using EMPIRICAL
# Done.
# Done.
# Computing rank from data with rank=None
# Computing rank from data with rank=None
#     Using tolerance 1.2e-05 (2.2e-16 eps * 8 dim * 6.9e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
#     Using tolerance 4e-06 (2.2e-16 eps * 8 dim * 2.3e+09  max singular value)
# Done.
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# Computing rank from data with rank=None
#     Using tolerance 3.3e-06 (2.2e-16 eps * 8 dim * 1.8e+09  max singular value)
#     Estimated rank (mag): 8
#     MAG: rank 8 computed from 8 data channels with 0 projectors
# Reducing data rank from 8 -> 8
# Estimating covariance using EMPIRICAL
# Done.
# 6 done| [16 22 29 34  9]
# 5 done| [15 21 28 33  8]
# (1500, 8, 65) (1500, 6)
# ========= close ========

# %%
X,Y = shuffle(X,Y)
bands = []
for filt in filter_list:
    pt = np.argwhere((freq >= filt[0]) & (freq <= filt[1])).reshape(-1)
    bands.append(pt)
bands = np.array(bands)

result_audio = []
best_audio = 0
best_audio_idx = -1
best_audio_comb = None
for r in [1,2,3,4,5]:
    print("="*20,f"Number {r}","="*20)
    for comb in combinations([0,1,2,3,4],r):
        print(" ",band_names[list(comb)])
        selected_x = None
        # print(bands[ list(comb) ])
        for pt in bands[ list(comb) ]:
            # print(pt)
            if(type(selected_x) == type(None)): selected_x = X[:,:,pt].mean(axis=2)
            else:
                selected_x = np.concatenate([selected_x, X[:,:,pt].mean(axis=2)], axis=1)
        # print(selected_x.shape)
        # pts = np.concatenate( bands[ list(comb) ] )
        result = np.array(get_accuracy(selected_x,Y))
        print(" Averag accuracy:", result[:,0].mean(), "Average Score:", result[:,1].mean(), "Average Variance:", result[:,2].mean())
        result_audio.append(result)
        if(result[:,1].mean() > best_audio):
            best_audio = result[:,1].mean()
            best_audio_idx = len(result_audio)-1
            best_audio_comb = band_names[ list(comb) ]

print(f"Best Score is {best_audio} at index {best_audio_idx} with combination {best_audio_comb}")
# Out:
# /tmp/ipykernel_110312/1958830028.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   bands = np.array(bands)
# ==================== Number 1 ====================
#   ['Delta']
# h | Accuracy: 0.59 Scores: 0.57 (+/- 0.04)
# e | Accuracy: 0.64 Scores: 0.64 (+/- 0.04)
# x | Accuracy: 0.56 Scores: 0.55 (+/- 0.07)
# a | Accuracy: 0.64 Scores: 0.64 (+/- 0.08)
# c | Accuracy: 0.61 Scores: 0.60 (+/- 0.04)
# o | Accuracy: 0.64 Scores: 0.64 (+/- 0.08)
#  Averag accuracy: 0.6124444444444445 Average Score: 0.6082222222222223 Average Variance: 0.02872094637045376
#   ['Theta']
# h | Accuracy: 0.64 Scores: 0.62 (+/- 0.08)
# e | Accuracy: 0.73 Scores: 0.73 (+/- 0.06)
# x | Accuracy: 0.58 Scores: 0.58 (+/- 0.05)
# a | Accuracy: 0.64 Scores: 0.64 (+/- 0.03)
# c | Accuracy: 0.58 Scores: 0.58 (+/- 0.07)
# o | Accuracy: 0.68 Scores: 0.68 (+/- 0.09)
#  Averag accuracy: 0.644 Average Score: 0.637888888888889 Average Variance: 0.031505536525695814
#   ['Alpha']
# h | Accuracy: 0.71 Scores: 0.70 (+/- 0.05)
# e | Accuracy: 0.70 Scores: 0.70 (+/- 0.08)
# x | Accuracy: 0.65 Scores: 0.66 (+/- 0.02)
# a | Accuracy: 0.69 Scores: 0.68 (+/- 0.02)
# c | Accuracy: 0.63 Scores: 0.62 (+/- 0.06)
# o | Accuracy: 0.65 Scores: 0.63 (+/- 0.07)
#  Averag accuracy: 0.6706666666666666 Average Score: 0.6672222222222222 Average Variance: 0.023995242505895603
#   ['Beta']
# h | Accuracy: 0.70 Scores: 0.70 (+/- 0.02)
# e | Accuracy: 0.76 Scores: 0.76 (+/- 0.06)
# x | Accuracy: 0.65 Scores: 0.64 (+/- 0.07)
# a | Accuracy: 0.66 Scores: 0.66 (+/- 0.06)
# c | Accuracy: 0.63 Scores: 0.63 (+/- 0.06)
# o | Accuracy: 0.75 Scores: 0.75 (+/- 0.04)
#  Averag accuracy: 0.6927777777777777 Average Score: 0.6897777777777777 Average Variance: 0.025609115067399105
#   ['Gamma']
# h | Accuracy: 0.63 Scores: 0.62 (+/- 0.06)
# e | Accuracy: 0.71 Scores: 0.71 (+/- 0.04)
# x | Accuracy: 0.64 Scores: 0.64 (+/- 0.09)
# a | Accuracy: 0.76 Scores: 0.76 (+/- 0.04)
# c | Accuracy: 0.63 Scores: 0.63 (+/- 0.07)
# o | Accuracy: 0.72 Scores: 0.72 (+/- 0.04)
#  Averag accuracy: 0.6822222222222223 Average Score: 0.6794444444444444 Average Variance: 0.027245399097711412
# ==================== Number 2 ====================
#   ['Delta' 'Theta']
# h | Accuracy: 0.64 Scores: 0.63 (+/- 0.10)
# e | Accuracy: 0.71 Scores: 0.71 (+/- 0.05)
# x | Accuracy: 0.58 Scores: 0.58 (+/- 0.05)
# a | Accuracy: 0.68 Scores: 0.67 (+/- 0.04)
# c | Accuracy: 0.60 Scores: 0.60 (+/- 0.09)
# o | Accuracy: 0.68 Scores: 0.67 (+/- 0.08)
#  Averag accuracy: 0.6481111111111111 Average Score: 0.6421111111111112 Average Variance: 0.033933424867842205
#   ['Delta' 'Alpha']
# h | Accuracy: 0.68 Scores: 0.67 (+/- 0.05)
# e | Accuracy: 0.73 Scores: 0.73 (+/- 0.06)
# x | Accuracy: 0.62 Scores: 0.61 (+/- 0.06)
# a | Accuracy: 0.72 Scores: 0.71 (+/- 0.06)
# c | Accuracy: 0.63 Scores: 0.63 (+/- 0.08)
# o | Accuracy: 0.67 Scores: 0.67 (+/- 0.08)
#  Averag accuracy: 0.6762222222222222 Average Score: 0.6702222222222223 Average Variance: 0.03200851428640602
#   ['Delta' 'Beta']
# h | Accuracy: 0.68 Scores: 0.68 (+/- 0.05)
# e | Accuracy: 0.75 Scores: 0.74 (+/- 0.05)
# x | Accuracy: 0.62 Scores: 0.60 (+/- 0.05)
# a | Accuracy: 0.71 Scores: 0.70 (+/- 0.03)
# c | Accuracy: 0.63 Scores: 0.63 (+/- 0.07)
# o | Accuracy: 0.70 Scores: 0.70 (+/- 0.08)
#  Averag accuracy: 0.6823333333333332 Average Score: 0.6742222222222222 Average Variance: 0.027873307216045945
#   ['Delta' 'Gamma']
# h | Accuracy: 0.63 Scores: 0.62 (+/- 0.05)
# e | Accuracy: 0.70 Scores: 0.70 (+/- 0.04)
# x | Accuracy: 0.65 Scores: 0.64 (+/- 0.06)
# a | Accuracy: 0.79 Scores: 0.77 (+/- 0.06)
# c | Accuracy: 0.65 Scores: 0.65 (+/- 0.07)
# o | Accuracy: 0.68 Scores: 0.68 (+/- 0.05)
#  Averag accuracy: 0.6838888888888889 Average Score: 0.676888888888889 Average Variance: 0.026858588652775513
#   ['Theta' 'Alpha']
# h | Accuracy: 0.69 Scores: 0.69 (+/- 0.05)
# e | Accuracy: 0.75 Scores: 0.74 (+/- 0.06)
# x | Accuracy: 0.62 Scores: 0.62 (+/- 0.04)
# a | Accuracy: 0.71 Scores: 0.71 (+/- 0.01)
# c | Accuracy: 0.62 Scores: 0.63 (+/- 0.09)
# o | Accuracy: 0.70 Scores: 0.70 (+/- 0.07)
#  Averag accuracy: 0.6831111111111111 Average Score: 0.6798888888888888 Average Variance: 0.026009448827930104
#   ['Theta' 'Beta']
# h | Accuracy: 0.70 Scores: 0.69 (+/- 0.04)
# e | Accuracy: 0.78 Scores: 0.77 (+/- 0.06)
# x | Accuracy: 0.63 Scores: 0.63 (+/- 0.03)
# a | Accuracy: 0.66 Scores: 0.65 (+/- 0.05)
# c | Accuracy: 0.62 Scores: 0.62 (+/- 0.06)
# o | Accuracy: 0.72 Scores: 0.72 (+/- 0.05)
#  Averag accuracy: 0.6826666666666666 Average Score: 0.6787777777777778 Average Variance: 0.025679808416056115
#   ['Theta' 'Gamma']
# h | Accuracy: 0.65 Scores: 0.64 (+/- 0.05)
# e | Accuracy: 0.76 Scores: 0.75 (+/- 0.07)
# x | Accuracy: 0.67 Scores: 0.65 (+/- 0.04)
# a | Accuracy: 0.76 Scores: 0.75 (+/- 0.03)
# c | Accuracy: 0.64 Scores: 0.64 (+/- 0.08)
# o | Accuracy: 0.72 Scores: 0.72 (+/- 0.05)
#  Averag accuracy: 0.7003333333333334 Average Score: 0.6920000000000001 Average Variance: 0.025904353478432455
#   ['Alpha' 'Beta']
# h | Accuracy: 0.71 Scores: 0.70 (+/- 0.05)
# e | Accuracy: 0.80 Scores: 0.80 (+/- 0.08)
# x | Accuracy: 0.67 Scores: 0.66 (+/- 0.03)
# a | Accuracy: 0.70 Scores: 0.69 (+/- 0.05)
# c | Accuracy: 0.65 Scores: 0.65 (+/- 0.05)
# o | Accuracy: 0.71 Scores: 0.71 (+/- 0.04)
#  Averag accuracy: 0.708111111111111 Average Score: 0.701888888888889 Average Variance: 0.025313390301232242
#   ['Alpha' 'Gamma']
# h | Accuracy: 0.69 Scores: 0.68 (+/- 0.05)
# e | Accuracy: 0.77 Scores: 0.77 (+/- 0.06)
# x | Accuracy: 0.70 Scores: 0.70 (+/- 0.05)
# a | Accuracy: 0.78 Scores: 0.78 (+/- 0.03)
# c | Accuracy: 0.65 Scores: 0.65 (+/- 0.06)
# o | Accuracy: 0.73 Scores: 0.73 (+/- 0.04)
#  Averag accuracy: 0.7214444444444444 Average Score: 0.7172222222222223 Average Variance: 0.02340633741307026
#   ['Beta' 'Gamma']
# h | Accuracy: 0.66 Scores: 0.66 (+/- 0.06)
# e | Accuracy: 0.73 Scores: 0.74 (+/- 0.07)
# x | Accuracy: 0.65 Scores: 0.65 (+/- 0.09)
# a | Accuracy: 0.76 Scores: 0.76 (+/- 0.03)
# c | Accuracy: 0.63 Scores: 0.63 (+/- 0.08)
# o | Accuracy: 0.74 Scores: 0.73 (+/- 0.04)
#  Averag accuracy: 0.6951111111111111 Average Score: 0.6933333333333332 Average Variance: 0.029938996877863392
# ==================== Number 3 ====================
#   ['Delta' 'Theta' 'Alpha']
# h | Accuracy: 0.68 Scores: 0.67 (+/- 0.06)
# e | Accuracy: 0.75 Scores: 0.75 (+/- 0.06)
# x | Accuracy: 0.60 Scores: 0.60 (+/- 0.04)
# a | Accuracy: 0.71 Scores: 0.71 (+/- 0.06)
# c | Accuracy: 0.63 Scores: 0.62 (+/- 0.10)
# o | Accuracy: 0.69 Scores: 0.68 (+/- 0.07)
#  Averag accuracy: 0.6771111111111111 Average Score: 0.6706666666666666 Average Variance: 0.0326390926919603
#   ['Delta' 'Theta' 'Beta']
# h | Accuracy: 0.69 Scores: 0.68 (+/- 0.06)
# e | Accuracy: 0.77 Scores: 0.77 (+/- 0.05)
# x | Accuracy: 0.62 Scores: 0.61 (+/- 0.05)
# a | Accuracy: 0.69 Scores: 0.68 (+/- 0.03)
# c | Accuracy: 0.63 Scores: 0.63 (+/- 0.05)
# o | Accuracy: 0.70 Scores: 0.70 (+/- 0.06)
#  Averag accuracy: 0.6828888888888889 Average Score: 0.6791111111111111 Average Variance: 0.025304730698468215
#   ['Delta' 'Theta' 'Gamma']
# h | Accuracy: 0.65 Scores: 0.64 (+/- 0.07)
# e | Accuracy: 0.74 Scores: 0.74 (+/- 0.07)
# x | Accuracy: 0.64 Scores: 0.64 (+/- 0.05)
# a | Accuracy: 0.77 Scores: 0.76 (+/- 0.05)
# c | Accuracy: 0.66 Scores: 0.66 (+/- 0.08)
# o | Accuracy: 0.70 Scores: 0.70 (+/- 0.07)
#  Averag accuracy: 0.6936666666666667 Average Score: 0.6895555555555556 Average Variance: 0.032787939649328725
#   ['Delta' 'Alpha' 'Beta']
# h | Accuracy: 0.71 Scores: 0.70 (+/- 0.03)
# e | Accuracy: 0.80 Scores: 0.79 (+/- 0.07)
# x | Accuracy: 0.66 Scores: 0.65 (+/- 0.07)
# a | Accuracy: 0.73 Scores: 0.73 (+/- 0.02)
# c | Accuracy: 0.65 Scores: 0.64 (+/- 0.06)
# o | Accuracy: 0.70 Scores: 0.69 (+/- 0.06)
#  Averag accuracy: 0.7057777777777777 Average Score: 0.7002222222222224 Average Variance: 0.02567387694798706
#   ['Delta' 'Alpha' 'Gamma']
# h | Accuracy: 0.68 Scores: 0.67 (+/- 0.07)
# e | Accuracy: 0.77 Scores: 0.77 (+/- 0.07)
# x | Accuracy: 0.69 Scores: 0.67 (+/- 0.06)
# a | Accuracy: 0.79 Scores: 0.79 (+/- 0.03)
# c | Accuracy: 0.66 Scores: 0.66 (+/- 0.07)
# o | Accuracy: 0.70 Scores: 0.70 (+/- 0.06)
#  Averag accuracy: 0.7141111111111113 Average Score: 0.710111111111111 Average Variance: 0.029208987340309783
#   ['Delta' 'Beta' 'Gamma']
# h | Accuracy: 0.66 Scores: 0.65 (+/- 0.08)
# e | Accuracy: 0.73 Scores: 0.73 (+/- 0.06)
# x | Accuracy: 0.65 Scores: 0.64 (+/- 0.04)
# a | Accuracy: 0.78 Scores: 0.77 (+/- 0.02)
# c | Accuracy: 0.64 Scores: 0.64 (+/- 0.07)
# o | Accuracy: 0.71 Scores: 0.71 (+/- 0.06)
#  Averag accuracy: 0.6948888888888889 Average Score: 0.6898888888888889 Average Variance: 0.02748363859008433
#   ['Theta' 'Alpha' 'Beta']
# h | Accuracy: 0.71 Scores: 0.71 (+/- 0.05)
# e | Accuracy: 0.80 Scores: 0.80 (+/- 0.07)
# x | Accuracy: 0.66 Scores: 0.66 (+/- 0.04)
# a | Accuracy: 0.71 Scores: 0.70 (+/- 0.04)
# c | Accuracy: 0.64 Scores: 0.64 (+/- 0.06)
# o | Accuracy: 0.71 Scores: 0.71 (+/- 0.06)
#  Averag accuracy: 0.7055555555555554 Average Score: 0.7026666666666667 Average Variance: 0.026256387473533593
#   ['Theta' 'Alpha' 'Gamma']
# h | Accuracy: 0.71 Scores: 0.69 (+/- 0.05)
# e | Accuracy: 0.78 Scores: 0.78 (+/- 0.06)
# x | Accuracy: 0.69 Scores: 0.68 (+/- 0.06)
# a | Accuracy: 0.78 Scores: 0.78 (+/- 0.03)
# c | Accuracy: 0.65 Scores: 0.65 (+/- 0.07)
# o | Accuracy: 0.72 Scores: 0.72 (+/- 0.04)
#  Averag accuracy: 0.7234444444444444 Average Score: 0.7163333333333334 Average Variance: 0.02667644320008918
#   ['Theta' 'Beta' 'Gamma']
# h | Accuracy: 0.68 Scores: 0.67 (+/- 0.06)
# e | Accuracy: 0.77 Scores: 0.77 (+/- 0.07)
# x | Accuracy: 0.68 Scores: 0.67 (+/- 0.04)
# a | Accuracy: 0.76 Scores: 0.76 (+/- 0.03)
# c | Accuracy: 0.64 Scores: 0.64 (+/- 0.07)
# o | Accuracy: 0.74 Scores: 0.74 (+/- 0.06)
#  Averag accuracy: 0.7118888888888889 Average Score: 0.7064444444444445 Average Variance: 0.027154812852692462
#   ['Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.70 Scores: 0.70 (+/- 0.07)
# e | Accuracy: 0.79 Scores: 0.78 (+/- 0.09)
# x | Accuracy: 0.71 Scores: 0.70 (+/- 0.05)
# a | Accuracy: 0.78 Scores: 0.77 (+/- 0.02)
# c | Accuracy: 0.64 Scores: 0.64 (+/- 0.05)
# o | Accuracy: 0.74 Scores: 0.74 (+/- 0.05)
#  Averag accuracy: 0.7244444444444444 Average Score: 0.7214444444444444 Average Variance: 0.027295602051270542
# ==================== Number 4 ====================
#   ['Delta' 'Theta' 'Alpha' 'Beta']
# h | Accuracy: 0.71 Scores: 0.70 (+/- 0.04)
# e | Accuracy: 0.80 Scores: 0.80 (+/- 0.07)
# x | Accuracy: 0.64 Scores: 0.64 (+/- 0.06)
# a | Accuracy: 0.72 Scores: 0.72 (+/- 0.02)
# c | Accuracy: 0.64 Scores: 0.64 (+/- 0.07)
# o | Accuracy: 0.70 Scores: 0.70 (+/- 0.06)
#  Averag accuracy: 0.7026666666666667 Average Score: 0.6995555555555555 Average Variance: 0.02660264004616116
#   ['Delta' 'Theta' 'Alpha' 'Gamma']
# h | Accuracy: 0.70 Scores: 0.69 (+/- 0.06)
# e | Accuracy: 0.79 Scores: 0.78 (+/- 0.07)
# x | Accuracy: 0.66 Scores: 0.65 (+/- 0.05)
# a | Accuracy: 0.78 Scores: 0.77 (+/- 0.05)
# c | Accuracy: 0.66 Scores: 0.66 (+/- 0.08)
# o | Accuracy: 0.70 Scores: 0.70 (+/- 0.07)
#  Averag accuracy: 0.715 Average Score: 0.707 Average Variance: 0.03257122376210302
#   ['Delta' 'Theta' 'Beta' 'Gamma']
# h | Accuracy: 0.67 Scores: 0.66 (+/- 0.08)
# e | Accuracy: 0.77 Scores: 0.77 (+/- 0.07)
# x | Accuracy: 0.65 Scores: 0.64 (+/- 0.04)
# a | Accuracy: 0.76 Scores: 0.75 (+/- 0.01)
# c | Accuracy: 0.64 Scores: 0.64 (+/- 0.08)
# o | Accuracy: 0.72 Scores: 0.72 (+/- 0.07)
#  Averag accuracy: 0.7027777777777776 Average Score: 0.6966666666666667 Average Variance: 0.028873745644313092
#   ['Delta' 'Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.70 Scores: 0.70 (+/- 0.06)
# e | Accuracy: 0.79 Scores: 0.78 (+/- 0.08)
# x | Accuracy: 0.70 Scores: 0.68 (+/- 0.03)
# a | Accuracy: 0.79 Scores: 0.78 (+/- 0.02)
# c | Accuracy: 0.64 Scores: 0.64 (+/- 0.07)
# o | Accuracy: 0.72 Scores: 0.72 (+/- 0.06)
#  Averag accuracy: 0.7237777777777777 Average Score: 0.7168888888888888 Average Variance: 0.026778464099707827
#   ['Theta' 'Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.72 Scores: 0.70 (+/- 0.05)
# e | Accuracy: 0.79 Scores: 0.79 (+/- 0.07)
# x | Accuracy: 0.69 Scores: 0.69 (+/- 0.04)
# a | Accuracy: 0.77 Scores: 0.76 (+/- 0.03)
# c | Accuracy: 0.64 Scores: 0.64 (+/- 0.07)
# o | Accuracy: 0.73 Scores: 0.73 (+/- 0.05)
#  Averag accuracy: 0.7240000000000001 Average Score: 0.7188888888888889 Average Variance: 0.025355052075280066
# ==================== Number 5 ====================
#   ['Delta' 'Theta' 'Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.72 Scores: 0.70 (+/- 0.05)
# e | Accuracy: 0.80 Scores: 0.79 (+/- 0.07)
# x | Accuracy: 0.68 Scores: 0.67 (+/- 0.05)
# a | Accuracy: 0.77 Scores: 0.76 (+/- 0.03)
# c | Accuracy: 0.65 Scores: 0.65 (+/- 0.08)
# o | Accuracy: 0.72 Scores: 0.72 (+/- 0.06)
#  Averag accuracy: 0.7228888888888889 Average Score: 0.714111111111111 Average Variance: 0.028992444111535957
# Best Score is 0.7214444444444444 at index 24 with combination ['Alpha' 'Beta' 'Gamma']

# %%
result_image = np.array(result_image)
result_audio = np.array(result_audio)

# %%
traits = ["h","e","x","a","c","o"]
width =.35

fig, ax = plt.subplots(figsize=(12,8))

ax.bar(np.arange(6)      ,result_image[best_image_idx,:,0] * 100, width=width, label='image', ecolor='black', capsize=10)
ax.bar(np.arange(6)+width,result_audio[best_audio_idx,:,0] * 100, width=width, label='audio', ecolor='black', capsize=10)

ax.set_xlabel('Traits')
ax.set_ylabel('Accuracy (%)')
ax.set_title('Accuracy of each trait prediction')
ax.set_xticks(np.arange(6) + width / 2)
ax.set_xticklabels(traits)
ax.legend()

plt.show()

# %%
print(f"On average, image accuracy is {round(result_image[best_image_idx,:,0].mean(),2)} and audio accuracy is {round(result_audio[best_audio_idx,:,0].mean(),2)}")
print(f"On average, image    score is {round(result_image[best_image_idx,:,1].mean(),2)} and audio    score is {round(result_audio[best_audio_idx,:,1].mean(),2)}")
print(f"On average, image      std is {round(result_image[best_image_idx,:,2].mean(),2)} and audio      std is {round(result_audio[best_audio_idx,:,2].mean(),2)}")
# Out:
# On average, image accuracy is 0.7 and audio accuracy is 0.72
# On average, image    score is 0.69 and audio    score is 0.72
# On average, image      std is 0.03 and audio      std is 0.03

# %%
for index, trait in enumerate(traits):
    print(f"Image {trait}: Acc: {round(result_image[best_image_idx,index,0],2)} | score: {round(result_image[best_image_idx,index,1],2)} | std: score: {round(result_image[best_image_idx,index,2],2)}" )
    print(f"Audio {trait}: Acc: {round(result_audio[best_audio_idx,index,0],2)} | score: {round(result_audio[best_audio_idx,index,1],2)} | std: score: {round(result_audio[best_audio_idx,index,2],2)}" )
    print()
print(f"Image: Best Score is {best_image} at index {best_image_idx} with combination {best_image_comb}")
print(f"Audio: Best Score is {best_audio} at index {best_audio_idx} with combination {best_audio_comb}")
# Out:
# Image h: Acc: 0.74 | score: 0.74 | std: score: 0.03
# Audio h: Acc: 0.7 | score: 0.7 | std: score: 0.03
#
# Image e: Acc: 0.69 | score: 0.69 | std: score: 0.04
# Audio e: Acc: 0.79 | score: 0.78 | std: score: 0.04
#
# Image x: Acc: 0.73 | score: 0.72 | std: score: 0.01
# Audio x: Acc: 0.71 | score: 0.7 | std: score: 0.03
#
# Image a: Acc: 0.72 | score: 0.72 | std: score: 0.03
# Audio a: Acc: 0.78 | score: 0.77 | std: score: 0.01
#
# Image c: Acc: 0.68 | score: 0.68 | std: score: 0.02
# Audio c: Acc: 0.64 | score: 0.64 | std: score: 0.02
#
# Image o: Acc: 0.63 | score: 0.62 | std: score: 0.02
# Audio o: Acc: 0.74 | score: 0.74 | std: score: 0.02
#
# Image: Best Score is 0.6944444444444443 at index 24 with combination ['Alpha' 'Beta' 'Gamma']
# Audio: Best Score is 0.7214444444444444 at index 24 with combination ['Alpha' 'Beta' 'Gamma']
