# %%
import pandas
import numpy as np
from utils import *
import mne
import matplotlib.pyplot as plt
from os import walk
from sklearn.decomposition import FastICA
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.model_selection import cross_val_score
from itertools import combinations
from sklearn.preprocessing import normalize
from sklearn.utils import shuffle
from tqdm.notebook import tqdm
import pickle

from multiprocessing import Pool
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# # Groud truth - Median

# %%
df = pandas.read_csv('./HEXACO.csv')
# Honesty-Humility	Emotionality	eXtraversion	Agreeableness	Conscientiousness	Openness to Experience
gt = df[['id','Honesty-Humility','Emotionality','eXtraversion','Agreeableness','Conscientiousness','Openness to Experience']].rename(columns={'Honesty-Humility':'h',
                                  'Emotionality':'e',
                                  'eXtraversion':'x',
                                 'Agreeableness':'a',
                             'Conscientiousness':'c',
                        'Openness to Experience':'o'}).set_index('id')

gt['lh'] = (gt[['h']] > np.median(gt['h'])) * 1
gt['le'] = (gt[['e']] > np.median(gt['e'])) * 1
gt['lx'] = (gt[['x']] > np.median(gt['x'])) * 1
gt['la'] = (gt[['a']] > np.median(gt['a'])) * 1
gt['lc'] = (gt[['c']] > np.median(gt['c'])) * 1
gt['lo'] = (gt[['o']] > np.median(gt['o'])) * 1
gt
# Out:
#        h     e     x     a     c     o  lh  le  lx  la  lc  lo
# id
# 2   3.63  3.19  2.94  2.38  3.38  2.38   1   0   0   0   0   0
# 3   3.38  3.44  3.50  3.50  4.50  3.81   0   0   1   1   1   1
# 4   3.19  3.75  3.69  3.19  2.63  2.63   0   1   1   0   0   0
# 5   3.25  3.63  2.13  3.56  3.63  2.31   0   1   0   1   1   0
# 6   3.25  2.75  3.50  2.50  3.75  5.00   0   0   1   0   1   1
# 7   4.06  3.06  3.38  2.88  2.50  4.19   1   0   1   0   0   1
# 8   3.94  2.94  3.19  3.75  3.38  3.81   1   0   1   1   0   1
# 9   4.44  4.00  3.38  3.75  3.69  3.31   1   1   1   1   1   0
# 10  3.63  3.25  3.50  3.31  3.88  2.69   1   0   1   1   1   0
# 11  3.31  4.00  2.25  3.19  2.81  3.19   0   1   0   0   0   0
# 12  2.81  3.44  3.13  3.56  3.25  3.75   0   0   1   1   0   1
# 13  3.06  3.06  3.00  2.69  3.31  3.44   0   0   0   0   0   0
# 14  4.63  3.69  2.25  3.13  2.94  2.63   1   1   0   0   0   0
# 15  3.75  2.94  2.94  3.50  4.19  3.19   1   0   0   1   1   0
# 16  4.19  4.25  1.88  2.81  3.25  3.81   1   1   0   0   0   1
# 17  4.25  3.00  4.00  2.50  3.25  3.25   1   0   1   0   0   0
# 18  2.81  3.31  2.06  2.75  3.00  3.19   0   0   0   0   0   0
# 20  3.25  3.31  4.31  3.44  2.00  4.25   0   0   1   1   0   1
# 21  4.06  3.00  2.88  3.56  3.81  3.81   1   0   0   1   1   1
# 22  3.50  3.88  1.88  2.63  3.94  3.69   0   1   0   0   1   1
# 23  3.13  4.19  3.00  2.38  2.88  3.88   0   1   0   0   0   1
# 25  3.25  3.44  3.75  3.50  3.88  3.44   0   0   1   1   1   0
# 26  3.50  3.19  2.44  2.94  2.44  3.25   0   0   0   0   0   0
# 27  2.63  3.88  3.81  3.88  3.31  3.88   0   1   1   1   0   1
# 28  3.19  4.31  2.19  1.88  2.56  3.25   0   1   0   0   0   0
# 29  3.56  4.38  2.06  2.94  3.44  4.56   1   1   0   0   1   1
# 30  4.50  3.81  2.44  3.13  2.94  4.31   1   1   0   0   0   1
# 31  4.06  3.56  2.63  3.31  3.75  4.06   1   1   0   1   1   1
# 32  2.75  3.25  3.75  2.81  3.06  3.31   0   0   1   0   0   0
# 33  4.00  3.56  2.38  3.63  3.63  3.19   1   1   0   1   1   0
# 34  3.38  2.69  3.69  3.31  3.81  3.50   0   0   1   1   1   0
# 35  3.69  3.44  3.56  4.00  3.38  4.38   1   0   1   1   0   1
# 36  3.56  4.56  3.31  3.63  4.38  4.31   1   1   1   1   1   1

# %%
fig, ax = plt.subplots(figsize=(16,9))
ax.bar(['H','E','X','A','C','O'],[ sum(gt['lh']), sum(gt['le']), sum(gt['lx']), sum(gt['la']), sum(gt['lc']), sum(gt['lo'])  ])
ax.set_title("Distribution of Labels")
ax.set_xlabel("Labels")
# ax.set_ylabel("Distribution of Labels")
plt.show()

# %% [markdown]
# # EEG data

# %%
def load_data():
    path, folders, filenames = next(walk('./data'))

    filenames.remove('11-audio.csv')
    filenames.remove('11-image.csv')

    filenames.remove('36-audio.csv')
    filenames.remove('36-image.csv')

    path = './data'
    columns = {'Unnamed: 1':'Fp1',
            'Unnamed: 2':'Fp2',
            'Unnamed: 3':'F3',
            'Unnamed: 4':'F4',
            'Unnamed: 5':'F7',
            'Unnamed: 6':'F8',
            'Unnamed: 7':'P7',
            'Unnamed: 8':'P8'}

    EEG_audio, EEG_image = dict(), dict()
    from itertools import product
    categories = [1,2,3,4,5]
    blocks = [1,2]
    with tqdm(filenames) as t:
        for filename in t:
            t.set_description(f"{filename}")
            participant_id, stimuli = filename.split('-')
            stimuli = stimuli.rstrip('.csv')
            data = pandas.read_csv(f'{path}/{filename}', dtype={'Marker': str}).rename(columns=columns).drop(columns='timestamps')
            # Aviod warning on stim has negative value
            marker = np.array(data['Marker'])
            marker[marker == '-1'] = '1'
            data['Marker'] = marker

            if(stimuli == 'audio'):
                EEG_audio[int(participant_id)] = data
            elif(stimuli == 'image'):
                EEG_image[int(participant_id)] = data
            else:
                raise ValueError(f"Stimuli:{stimuli} is unexpected.")
    return EEG_audio, EEG_image

# %%
# clear_cache()
try:
    # Load from cache
    EEG_audio = load('EEG_audio')
    EEG_image = load('EEG_image')
    print('Load data from cache')
    if( set(EEG_audio.keys()) != set(EEG_image.keys()) ):
        extra = None
        if(len(EEG_audio.keys()) > len(EEG_image.keys())):
            extra = set(EEG_audio.keys()).difference( set(EEG_image.keys()) )
        else:
            extra = set(EEG_image.keys()).difference( set(EEG_audio.keys()) )
        raise ValueError(f"In equal keys. audio has {len(EEG_audio.keys())} and image has {len(EEG_image.keys())}. The extra key is {extra}")

except FileNotFoundError as e:
    EEG_audio, EEG_image = load_data()
    # Save to cache
    save(EEG_audio, 'EEG_audio')
    save(EEG_image, 'EEG_image')
# Out:
# Load data from cache

# %% [markdown]
# # Pre process with PSD + log

# %%
# filter_list = [[0,4],[4,8],[8,13],[13,30],[30,125]]
# raw = dataframe_to_raw(EEG_image[33], sfreq=250)
            
# # Preprocess
# raw.notch_filter([50,100],filter_length='auto', phase='zero', verbose=False) # Line power
# raw.filter(1., None, verbose=False) # Slow drift
# ica = mne.preprocessing.ICA(n_components=8, max_iter='auto')
# ica.fit(raw, verbose=False)
# raw = ica.apply(raw, verbose=False)

# events = mne.find_events(raw, stim_channel='Marker', initial_event=True, verbose=False, uint_cast=False)
# events = np.delete(events,np.argwhere(events[:,2] == 1), axis=0) # break
# # Check data
# if(events.shape[0] != 50):
#     raise ValueError(f"Event missing: {events[:,2]}. len(events.shape[0])={events.shape[0]}")
# epochs = mne.Epochs(raw, events, tmin=0.3, tmax=5.8, baseline=(0.3,0.3), verbose=False)
# if(epochs.get_data().shape[0] != 50):
#     raise ValueError(f"There might be a bad data. epochs.get_data().shape = {epochs.get_data().shape}")

# # Extract features

# for evoked in epochs.iter_evoked():
#     power,freq = mne.time_frequency.psd_array_welch(evoked.data,sfreq=250,n_fft=128, verbose=False)
#     break

# %%
# filt = filter_list[0]
# print(power.shape, freq)

# %%
# features = []
# for filt in filter_list:
#     a = np.argwhere((freq <= filt[1]) & (freq >= filt[0])).reshape(-1)
#     # print(a.reshape(-1))
#     features.append(list(power[:,a].mean(axis=0)))
#     # break
# np.array(features)

# %%
band_names = np.array(['Delta', 'Theta', 'Alpha', 'Beta', 'Gamma'])
filter_list = [[0,4],[4,8],[8,13],[13,30],[30,125]]
def build_data(p_num, EEG,ids):
    X = None
    Y = None
    t_start, t_stop = (2.5,3.5)
    with tqdm(ids) as t:
        for index, id in enumerate(t):
            t.set_description(f"{id}")
            print(f"p_no={p_num}|index={index}|id={id}")
            raw = dataframe_to_raw(EEG[id], sfreq=250)
            
            # Preprocess
            raw.notch_filter([50,100],filter_length='auto', phase='zero', verbose=False) # Line power
            raw.filter(1., None, verbose=False) # Slow drift
            ica = mne.preprocessing.ICA(n_components=8, max_iter='auto')
            ica.fit(raw, verbose=False)
            raw = ica.apply(raw, verbose=False)

            events = mne.find_events(raw, stim_channel='Marker', initial_event=True, verbose=False, uint_cast=False)
            events = np.delete(events,np.argwhere(events[:,2] == 1), axis=0) # break
            # Check data
            if(events.shape[0] != 50):
                raise ValueError(f"Event missing: {events[:,2]}. len(events.shape[0])={events.shape[0]}")
            epochs = mne.Epochs(raw, events, tmin=t_start, tmax=t_stop, baseline=(t_start,t_stop), verbose=False)
            if(epochs.get_data().shape[0] != 50):
                raise ValueError(f"There might be a bad data. epochs.get_data().shape = {epochs.get_data().shape}")

            # Extract features

            for evoked in epochs.iter_evoked():
                power,freq = mne.time_frequency.psd_array_welch(evoked.data,sfreq=250,n_fft=128, verbose=False)
                # print(power.shape, power[:8].shape)
                # row = power[:8].mean(axis=0)
                # row = np.expand_dims(row.reshape(-1), axis=0)
                row = power[:8]
                row = np.expand_dims(row, axis=0)
                row = 10 * np.log10(row)
                if(type(X) == type(None)): X = row
                else: X = np.concatenate( [X, row ], axis=0 )

                label = gt.loc[id][['lh','le','lx','la','lc','lo']].to_numpy()
                label = np.expand_dims(label, axis=0)
                if(type(Y) == type(None)): Y = label
                else: Y = np.concatenate( [Y, label ], axis=0 )

    print(f"{p_num} done| {ids}")
    return np.array(X),np.array(Y),freq

def get_accuracy(X,y):
    result = []
    traits = ["h","e","x","a","c","o"]
    for index,label in enumerate(traits):
        y = Y[:,index]
        X_copy = X.copy()
        X_copy = normalize(X_copy,axis=0)
        mnb = GaussianNB()
        mnb.fit(X_copy, y)
        acc = sum(mnb.predict(X_copy) == y) / len(y)
        scores = cross_val_score(mnb, X_copy, y)
        result.append([acc,scores.mean(),scores.std()])
        print(label,"| Accuracy: %0.2f Scores: %0.2f (+/- %0.2f)" % (acc,scores.mean(), scores.std() * 2))
    return result

# %%
try:
    # [33,2,10,12,16]
    t_out = 300
    pool = Pool()
    ids = np.array(list(EEG_image.keys()))
    p1 = pool.apply_async(build_data, [1,EEG_image,ids[0::6]])
    p2 = pool.apply_async(build_data, [2,EEG_image,ids[1::6]])
    p3 = pool.apply_async(build_data, [3,EEG_image,ids[2::6]])
    p4 = pool.apply_async(build_data, [4,EEG_image,ids[3::6]])
    p5 = pool.apply_async(build_data, [5,EEG_image,ids[4::6]])
    p6 = pool.apply_async(build_data, [6,EEG_image,ids[5::6]])
    ans1 = p1.get(timeout=t_out)
    ans2 = p2.get(timeout=t_out)
    ans3 = p3.get(timeout=t_out)
    ans4 = p4.get(timeout=t_out)
    ans5 = p5.get(timeout=t_out)
    ans6 = p6.get(timeout=t_out)
    X = np.concatenate([ans1[0] , ans2[0], ans3[0], ans4[0] ,ans5[0], ans6[0]])
    Y = np.concatenate([ans1[1] , ans2[1], ans3[1], ans4[1] ,ans5[1], ans6[1]])
    freq = ans1[2]
    print(X.shape, Y.shape)
finally:
    print("========= close ========")
    pool.close() 
    pool.terminate()
# Out:
# p_no=1|index=0|id=10
# p_no=2|index=0|id=12
# p_no=3|index=0|id=13
# p_no=4|index=0|id=14
# p_no=5|index=0|id=15
# p_no=6|index=0|id=16
# p_no=1|index=1|id=17
# p_no=2|index=1|id=18
# p_no=4|index=1|id=20p_no=5|index=1|id=21
#
# p_no=3|index=1|id=2
# p_no=6|index=1|id=22
# p_no=2|index=2|id=25
# p_no=3|index=2|id=26
# p_no=1|index=2|id=23
# p_no=4|index=2|id=27
# p_no=5|index=2|id=28
# p_no=6|index=2|id=29
# p_no=2|index=3|id=30
# p_no=3|index=3|id=31
# p_no=1|index=3|id=3
# p_no=4|index=3|id=32
# p_no=5|index=3|id=33
# p_no=6|index=3|id=34
# p_no=4|index=4|id=7
# /tmp/ipykernel_32138/53404167.py:17: RuntimeWarning: Using n_components=8 (resulting in n_components_=8) may lead to an unstable mixing matrix estimation because the ratio between the largest (8) and smallest (2.4e-06) variances is too large (> 1e6); consider setting n_components=0.999999 or an integer <= 5
#   ica.fit(raw, verbose=False)
# p_no=2|index=4|id=5
# p_no=3|index=4|id=6
# p_no=5|index=4|id=8
# p_no=1|index=4|id=35
# p_no=6|index=4|id=9
# 4 done| [14 20 27 32  7]
# 2 done| [12 18 25 30  5]
# 3 done| [13  2 26 31  6]
# 5 done| [15 21 28 33  8]
# 1 done| [10 17 23  3 35]
# 6 done| [16 22 29 34  9]
# (1500, 8, 65) (1500, 6)
# ========= close ========

# %%
X,Y = shuffle(X,Y)
bands = []
for filt in filter_list:
    pt = np.argwhere((freq >= filt[0]) & (freq <= filt[1])).reshape(-1)
    bands.append(pt)
bands = np.array(bands)

result_image = []
best_image = 0
best_image_idx = -1
best_image_comb = None
for r in [1,2,3,4,5]:
    print("="*20,f"Number {r}","="*20)
    for comb in combinations([0,1,2,3,4],r):
        print(" ",band_names[list(comb)])
        selected_x = None
        # print(bands[ list(comb) ])
        for pt in bands[ list(comb) ]:
            # print(pt)
            if(type(selected_x) == type(None)): selected_x = X[:,:,pt].mean(axis=2)
            else:
                selected_x = np.concatenate([selected_x, X[:,:,pt].mean(axis=2)], axis=1)
        # print(selected_x.shape)
        # pts = np.concatenate( bands[ list(comb) ] )
        result = np.array(get_accuracy(selected_x,Y))
        print(" Averag accuracy:", result[:,0].mean(), "Average Score:", result[:,1].mean(), "Average Variance:", result[:,2].mean())
        result_image.append(result)
        if(result[:,1].mean() > best_image):
            best_image = result[:,1].mean()
            best_image_idx = len(result_image)-1
            best_image_comb = band_names[ list(comb) ]

print(f"Best Score is {best_image} at index {best_image_idx} with combination {best_image_comb}")
# Out:
# /tmp/ipykernel_32138/1983967163.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   bands = np.array(bands)
# ==================== Number 1 ====================
#   ['Delta']
# h | Accuracy: 0.57 Scores: 0.55 (+/- 0.03)
# e | Accuracy: 0.60 Scores: 0.59 (+/- 0.04)
# x | Accuracy: 0.55 Scores: 0.55 (+/- 0.04)
# a | Accuracy: 0.52 Scores: 0.51 (+/- 0.07)
# c | Accuracy: 0.58 Scores: 0.58 (+/- 0.05)
# o | Accuracy: 0.51 Scores: 0.51 (+/- 0.02)
#  Averag accuracy: 0.5547777777777777 Average Score: 0.5485555555555556 Average Variance: 0.021832285415892962
#   ['Theta']
# h | Accuracy: 0.54 Scores: 0.54 (+/- 0.06)
# e | Accuracy: 0.58 Scores: 0.57 (+/- 0.06)
# x | Accuracy: 0.58 Scores: 0.57 (+/- 0.05)
# a | Accuracy: 0.50 Scores: 0.49 (+/- 0.09)
# c | Accuracy: 0.57 Scores: 0.56 (+/- 0.04)
# o | Accuracy: 0.56 Scores: 0.56 (+/- 0.03)
#  Averag accuracy: 0.5557777777777778 Average Score: 0.5473333333333333 Average Variance: 0.02685477993710242
#   ['Alpha']
# h | Accuracy: 0.54 Scores: 0.51 (+/- 0.04)
# e | Accuracy: 0.57 Scores: 0.56 (+/- 0.07)
# x | Accuracy: 0.56 Scores: 0.55 (+/- 0.04)
# a | Accuracy: 0.54 Scores: 0.52 (+/- 0.06)
# c | Accuracy: 0.55 Scores: 0.54 (+/- 0.03)
# o | Accuracy: 0.56 Scores: 0.54 (+/- 0.05)
#  Averag accuracy: 0.5516666666666666 Average Score: 0.5382222222222223 Average Variance: 0.02425716020774635
#   ['Beta']
# h | Accuracy: 0.63 Scores: 0.61 (+/- 0.03)
# e | Accuracy: 0.60 Scores: 0.60 (+/- 0.09)
# x | Accuracy: 0.58 Scores: 0.57 (+/- 0.07)
# a | Accuracy: 0.61 Scores: 0.60 (+/- 0.06)
# c | Accuracy: 0.65 Scores: 0.65 (+/- 0.04)
# o | Accuracy: 0.59 Scores: 0.58 (+/- 0.07)
#  Averag accuracy: 0.6104444444444445 Average Score: 0.6008888888888889 Average Variance: 0.030169488725856185
#   ['Gamma']
# h | Accuracy: 0.66 Scores: 0.65 (+/- 0.06)
# e | Accuracy: 0.68 Scores: 0.68 (+/- 0.05)
# x | Accuracy: 0.60 Scores: 0.59 (+/- 0.04)
# a | Accuracy: 0.64 Scores: 0.63 (+/- 0.04)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.04)
# o | Accuracy: 0.64 Scores: 0.63 (+/- 0.06)
#  Averag accuracy: 0.6525555555555554 Average Score: 0.6434444444444444 Average Variance: 0.024589673154161305
# ==================== Number 2 ====================
#   ['Delta' 'Theta']
# h | Accuracy: 0.55 Scores: 0.55 (+/- 0.04)
# e | Accuracy: 0.60 Scores: 0.59 (+/- 0.06)
# x | Accuracy: 0.58 Scores: 0.58 (+/- 0.04)
# a | Accuracy: 0.52 Scores: 0.50 (+/- 0.06)
# c | Accuracy: 0.59 Scores: 0.58 (+/- 0.05)
# o | Accuracy: 0.55 Scores: 0.54 (+/- 0.02)
#  Averag accuracy: 0.563888888888889 Average Score: 0.5578888888888889 Average Variance: 0.02290427178489196
#   ['Delta' 'Alpha']
# h | Accuracy: 0.57 Scores: 0.54 (+/- 0.01)
# e | Accuracy: 0.59 Scores: 0.59 (+/- 0.04)
# x | Accuracy: 0.56 Scores: 0.55 (+/- 0.02)
# a | Accuracy: 0.55 Scores: 0.53 (+/- 0.08)
# c | Accuracy: 0.58 Scores: 0.57 (+/- 0.05)
# o | Accuracy: 0.53 Scores: 0.52 (+/- 0.03)
#  Averag accuracy: 0.5612222222222222 Average Score: 0.5496666666666667 Average Variance: 0.019815234913113215
#   ['Delta' 'Beta']
# h | Accuracy: 0.64 Scores: 0.62 (+/- 0.04)
# e | Accuracy: 0.61 Scores: 0.60 (+/- 0.06)
# x | Accuracy: 0.58 Scores: 0.57 (+/- 0.09)
# a | Accuracy: 0.60 Scores: 0.59 (+/- 0.07)
# c | Accuracy: 0.65 Scores: 0.65 (+/- 0.07)
# o | Accuracy: 0.58 Scores: 0.57 (+/- 0.04)
#  Averag accuracy: 0.609 Average Score: 0.600111111111111 Average Variance: 0.029752203303851046
#   ['Delta' 'Gamma']
# h | Accuracy: 0.66 Scores: 0.64 (+/- 0.06)
# e | Accuracy: 0.66 Scores: 0.65 (+/- 0.02)
# x | Accuracy: 0.60 Scores: 0.59 (+/- 0.05)
# a | Accuracy: 0.61 Scores: 0.61 (+/- 0.07)
# c | Accuracy: 0.68 Scores: 0.68 (+/- 0.03)
# o | Accuracy: 0.64 Scores: 0.63 (+/- 0.04)
#  Averag accuracy: 0.6424444444444445 Average Score: 0.6344444444444445 Average Variance: 0.022481543300423925
#   ['Theta' 'Alpha']
# h | Accuracy: 0.55 Scores: 0.53 (+/- 0.04)
# e | Accuracy: 0.57 Scores: 0.57 (+/- 0.05)
# x | Accuracy: 0.59 Scores: 0.58 (+/- 0.07)
# a | Accuracy: 0.54 Scores: 0.51 (+/- 0.08)
# c | Accuracy: 0.56 Scores: 0.55 (+/- 0.03)
# o | Accuracy: 0.55 Scores: 0.54 (+/- 0.06)
#  Averag accuracy: 0.5587777777777778 Average Score: 0.5461111111111111 Average Variance: 0.027434656324449223
#   ['Theta' 'Beta']
# h | Accuracy: 0.63 Scores: 0.63 (+/- 0.03)
# e | Accuracy: 0.60 Scores: 0.59 (+/- 0.06)
# x | Accuracy: 0.60 Scores: 0.59 (+/- 0.04)
# a | Accuracy: 0.60 Scores: 0.60 (+/- 0.06)
# c | Accuracy: 0.65 Scores: 0.65 (+/- 0.03)
# o | Accuracy: 0.59 Scores: 0.59 (+/- 0.05)
#  Averag accuracy: 0.6124444444444445 Average Score: 0.6072222222222222 Average Variance: 0.02266277347361108
#   ['Theta' 'Gamma']
# h | Accuracy: 0.65 Scores: 0.63 (+/- 0.04)
# e | Accuracy: 0.65 Scores: 0.64 (+/- 0.06)
# x | Accuracy: 0.62 Scores: 0.61 (+/- 0.05)
# a | Accuracy: 0.63 Scores: 0.62 (+/- 0.07)
# c | Accuracy: 0.68 Scores: 0.68 (+/- 0.04)
# o | Accuracy: 0.64 Scores: 0.63 (+/- 0.07)
#  Averag accuracy: 0.6451111111111111 Average Score: 0.6354444444444445 Average Variance: 0.02662400659042398
#   ['Alpha' 'Beta']
# h | Accuracy: 0.62 Scores: 0.60 (+/- 0.03)
# e | Accuracy: 0.61 Scores: 0.60 (+/- 0.09)
# x | Accuracy: 0.58 Scores: 0.58 (+/- 0.06)
# a | Accuracy: 0.62 Scores: 0.62 (+/- 0.06)
# c | Accuracy: 0.65 Scores: 0.64 (+/- 0.06)
# o | Accuracy: 0.59 Scores: 0.58 (+/- 0.06)
#  Averag accuracy: 0.6127777777777778 Average Score: 0.6023333333333333 Average Variance: 0.02961606067795186
#   ['Alpha' 'Gamma']
# h | Accuracy: 0.66 Scores: 0.65 (+/- 0.07)
# e | Accuracy: 0.67 Scores: 0.66 (+/- 0.05)
# x | Accuracy: 0.62 Scores: 0.61 (+/- 0.05)
# a | Accuracy: 0.62 Scores: 0.61 (+/- 0.05)
# c | Accuracy: 0.68 Scores: 0.67 (+/- 0.04)
# o | Accuracy: 0.64 Scores: 0.63 (+/- 0.05)
#  Averag accuracy: 0.6472222222222221 Average Score: 0.6397777777777778 Average Variance: 0.0260860316253394
#   ['Beta' 'Gamma']
# h | Accuracy: 0.70 Scores: 0.68 (+/- 0.04)
# e | Accuracy: 0.65 Scores: 0.63 (+/- 0.08)
# x | Accuracy: 0.61 Scores: 0.61 (+/- 0.06)
# a | Accuracy: 0.65 Scores: 0.65 (+/- 0.05)
# c | Accuracy: 0.70 Scores: 0.70 (+/- 0.05)
# o | Accuracy: 0.65 Scores: 0.64 (+/- 0.05)
#  Averag accuracy: 0.66 Average Score: 0.6525555555555556 Average Variance: 0.02744394899621626
# ==================== Number 3 ====================
#   ['Delta' 'Theta' 'Alpha']
# h | Accuracy: 0.56 Scores: 0.55 (+/- 0.04)
# e | Accuracy: 0.60 Scores: 0.59 (+/- 0.04)
# x | Accuracy: 0.59 Scores: 0.58 (+/- 0.05)
# a | Accuracy: 0.54 Scores: 0.53 (+/- 0.08)
# c | Accuracy: 0.57 Scores: 0.56 (+/- 0.04)
# o | Accuracy: 0.54 Scores: 0.53 (+/- 0.03)
#  Averag accuracy: 0.5672222222222222 Average Score: 0.5563333333333333 Average Variance: 0.024307571406381775
#   ['Delta' 'Theta' 'Beta']
# h | Accuracy: 0.63 Scores: 0.62 (+/- 0.04)
# e | Accuracy: 0.62 Scores: 0.61 (+/- 0.04)
# x | Accuracy: 0.59 Scores: 0.58 (+/- 0.03)
# a | Accuracy: 0.60 Scores: 0.58 (+/- 0.08)
# c | Accuracy: 0.65 Scores: 0.64 (+/- 0.07)
# o | Accuracy: 0.58 Scores: 0.57 (+/- 0.04)
#  Averag accuracy: 0.6127777777777778 Average Score: 0.602 Average Variance: 0.026281263598306542
#   ['Delta' 'Theta' 'Gamma']
# h | Accuracy: 0.64 Scores: 0.63 (+/- 0.02)
# e | Accuracy: 0.63 Scores: 0.62 (+/- 0.04)
# x | Accuracy: 0.62 Scores: 0.61 (+/- 0.06)
# a | Accuracy: 0.60 Scores: 0.59 (+/- 0.08)
# c | Accuracy: 0.68 Scores: 0.68 (+/- 0.03)
# o | Accuracy: 0.62 Scores: 0.62 (+/- 0.04)
#  Averag accuracy: 0.6332222222222222 Average Score: 0.6237777777777778 Average Variance: 0.02302629366373783
#   ['Delta' 'Alpha' 'Beta']
# h | Accuracy: 0.63 Scores: 0.62 (+/- 0.03)
# e | Accuracy: 0.61 Scores: 0.60 (+/- 0.06)
# x | Accuracy: 0.58 Scores: 0.57 (+/- 0.05)
# a | Accuracy: 0.61 Scores: 0.60 (+/- 0.10)
# c | Accuracy: 0.65 Scores: 0.65 (+/- 0.07)
# o | Accuracy: 0.58 Scores: 0.57 (+/- 0.02)
#  Averag accuracy: 0.609 Average Score: 0.6004444444444444 Average Variance: 0.027339634567366763
#   ['Delta' 'Alpha' 'Gamma']
# h | Accuracy: 0.65 Scores: 0.63 (+/- 0.06)
# e | Accuracy: 0.65 Scores: 0.64 (+/- 0.03)
# x | Accuracy: 0.61 Scores: 0.59 (+/- 0.07)
# a | Accuracy: 0.61 Scores: 0.59 (+/- 0.07)
# c | Accuracy: 0.68 Scores: 0.67 (+/- 0.04)
# o | Accuracy: 0.64 Scores: 0.63 (+/- 0.05)
#  Averag accuracy: 0.6425555555555555 Average Score: 0.6257777777777778 Average Variance: 0.02663141713546119
#   ['Delta' 'Beta' 'Gamma']
# h | Accuracy: 0.70 Scores: 0.67 (+/- 0.04)
# e | Accuracy: 0.65 Scores: 0.64 (+/- 0.05)
# x | Accuracy: 0.60 Scores: 0.59 (+/- 0.06)
# a | Accuracy: 0.64 Scores: 0.63 (+/- 0.06)
# c | Accuracy: 0.70 Scores: 0.70 (+/- 0.05)
# o | Accuracy: 0.66 Scores: 0.65 (+/- 0.04)
#  Averag accuracy: 0.6583333333333333 Average Score: 0.6476666666666666 Average Variance: 0.02565135750582498
#   ['Theta' 'Alpha' 'Beta']
# h | Accuracy: 0.64 Scores: 0.61 (+/- 0.02)
# e | Accuracy: 0.60 Scores: 0.59 (+/- 0.04)
# x | Accuracy: 0.60 Scores: 0.59 (+/- 0.05)
# a | Accuracy: 0.61 Scores: 0.61 (+/- 0.09)
# c | Accuracy: 0.64 Scores: 0.64 (+/- 0.05)
# o | Accuracy: 0.59 Scores: 0.58 (+/- 0.07)
#  Averag accuracy: 0.6141111111111112 Average Score: 0.6043333333333334 Average Variance: 0.026779631336971362
#   ['Theta' 'Alpha' 'Gamma']
# h | Accuracy: 0.65 Scores: 0.63 (+/- 0.05)
# e | Accuracy: 0.64 Scores: 0.63 (+/- 0.05)
# x | Accuracy: 0.65 Scores: 0.62 (+/- 0.06)
# a | Accuracy: 0.61 Scores: 0.60 (+/- 0.06)
# c | Accuracy: 0.68 Scores: 0.67 (+/- 0.04)
# o | Accuracy: 0.62 Scores: 0.62 (+/- 0.05)
#  Averag accuracy: 0.6397777777777778 Average Score: 0.6273333333333334 Average Variance: 0.026793539734841068
#   ['Theta' 'Beta' 'Gamma']
# h | Accuracy: 0.69 Scores: 0.67 (+/- 0.05)
# e | Accuracy: 0.63 Scores: 0.62 (+/- 0.07)
# x | Accuracy: 0.63 Scores: 0.61 (+/- 0.05)
# a | Accuracy: 0.65 Scores: 0.64 (+/- 0.08)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.05)
# o | Accuracy: 0.62 Scores: 0.62 (+/- 0.05)
#  Averag accuracy: 0.6527777777777778 Average Score: 0.6397777777777778 Average Variance: 0.029506303683184895
#   ['Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.69 Scores: 0.66 (+/- 0.04)
# e | Accuracy: 0.64 Scores: 0.63 (+/- 0.06)
# x | Accuracy: 0.61 Scores: 0.60 (+/- 0.06)
# a | Accuracy: 0.66 Scores: 0.65 (+/- 0.08)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.06)
# o | Accuracy: 0.65 Scores: 0.64 (+/- 0.05)
#  Averag accuracy: 0.658 Average Score: 0.6468888888888888 Average Variance: 0.028856479888361198
# ==================== Number 4 ====================
#   ['Delta' 'Theta' 'Alpha' 'Beta']
# h | Accuracy: 0.64 Scores: 0.61 (+/- 0.03)
# e | Accuracy: 0.61 Scores: 0.61 (+/- 0.04)
# x | Accuracy: 0.60 Scores: 0.58 (+/- 0.04)
# a | Accuracy: 0.60 Scores: 0.59 (+/- 0.11)
# c | Accuracy: 0.65 Scores: 0.63 (+/- 0.07)
# o | Accuracy: 0.57 Scores: 0.57 (+/- 0.05)
#  Averag accuracy: 0.6112222222222222 Average Score: 0.5990000000000001 Average Variance: 0.02790915855949962
#   ['Delta' 'Theta' 'Alpha' 'Gamma']
# h | Accuracy: 0.64 Scores: 0.61 (+/- 0.04)
# e | Accuracy: 0.63 Scores: 0.62 (+/- 0.03)
# x | Accuracy: 0.63 Scores: 0.62 (+/- 0.05)
# a | Accuracy: 0.60 Scores: 0.59 (+/- 0.07)
# c | Accuracy: 0.67 Scores: 0.67 (+/- 0.03)
# o | Accuracy: 0.61 Scores: 0.60 (+/- 0.06)
#  Averag accuracy: 0.6316666666666667 Average Score: 0.618 Average Variance: 0.023992810685836415
#   ['Delta' 'Theta' 'Beta' 'Gamma']
# h | Accuracy: 0.68 Scores: 0.66 (+/- 0.05)
# e | Accuracy: 0.64 Scores: 0.63 (+/- 0.03)
# x | Accuracy: 0.61 Scores: 0.60 (+/- 0.06)
# a | Accuracy: 0.63 Scores: 0.62 (+/- 0.09)
# c | Accuracy: 0.70 Scores: 0.69 (+/- 0.05)
# o | Accuracy: 0.63 Scores: 0.63 (+/- 0.02)
#  Averag accuracy: 0.648 Average Score: 0.6386666666666666 Average Variance: 0.024873448772896063
#   ['Delta' 'Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.69 Scores: 0.66 (+/- 0.05)
# e | Accuracy: 0.64 Scores: 0.63 (+/- 0.06)
# x | Accuracy: 0.61 Scores: 0.58 (+/- 0.08)
# a | Accuracy: 0.64 Scores: 0.64 (+/- 0.08)
# c | Accuracy: 0.70 Scores: 0.69 (+/- 0.05)
# o | Accuracy: 0.64 Scores: 0.63 (+/- 0.06)
#  Averag accuracy: 0.6527777777777778 Average Score: 0.6378888888888888 Average Variance: 0.031044086932200708
#   ['Theta' 'Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.69 Scores: 0.66 (+/- 0.05)
# e | Accuracy: 0.63 Scores: 0.61 (+/- 0.05)
# x | Accuracy: 0.63 Scores: 0.62 (+/- 0.05)
# a | Accuracy: 0.65 Scores: 0.65 (+/- 0.08)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.04)
# o | Accuracy: 0.63 Scores: 0.62 (+/- 0.04)
#  Averag accuracy: 0.6536666666666667 Average Score: 0.6396666666666667 Average Variance: 0.025599657311449423
# ==================== Number 5 ====================
#   ['Delta' 'Theta' 'Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.68 Scores: 0.65 (+/- 0.04)
# e | Accuracy: 0.62 Scores: 0.62 (+/- 0.03)
# x | Accuracy: 0.63 Scores: 0.61 (+/- 0.06)
# a | Accuracy: 0.63 Scores: 0.64 (+/- 0.10)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.04)
# o | Accuracy: 0.63 Scores: 0.61 (+/- 0.04)
#  Averag accuracy: 0.6494444444444445 Average Score: 0.636 Average Variance: 0.026202415769077936
# Best Score is 0.6525555555555556 at index 14 with combination ['Beta' 'Gamma']

# %%
try:
    # [33,2,10,12,16]
    t_out = 300
    pool = Pool()
    ids = np.array(list(EEG_audio.keys()))
    p1 = pool.apply_async(build_data, [1,EEG_audio,ids[0::6]])
    p2 = pool.apply_async(build_data, [2,EEG_audio,ids[1::6]])
    p3 = pool.apply_async(build_data, [3,EEG_audio,ids[2::6]])
    p4 = pool.apply_async(build_data, [4,EEG_audio,ids[3::6]])
    p5 = pool.apply_async(build_data, [5,EEG_audio,ids[4::6]])
    p6 = pool.apply_async(build_data, [6,EEG_audio,ids[5::6]])
    ans1 = p1.get(timeout=t_out)
    ans2 = p2.get(timeout=t_out)
    ans3 = p3.get(timeout=t_out)
    ans4 = p4.get(timeout=t_out)
    ans5 = p5.get(timeout=t_out)
    ans6 = p6.get(timeout=t_out)
    X = np.concatenate([ans1[0] , ans2[0], ans3[0], ans4[0] ,ans5[0], ans6[0]])
    Y = np.concatenate([ans1[1] , ans2[1], ans3[1], ans4[1] ,ans5[1], ans6[1]])
    print(X.shape, Y.shape)
finally:
    print("========= close ========")
    pool.close() 
    pool.terminate()
# Out:
# p_no=1|index=0|id=10
# p_no=2|index=0|id=12
# p_no=3|index=0|id=13
# p_no=4|index=0|id=14
# p_no=5|index=0|id=15
# p_no=6|index=0|id=16
# p_no=1|index=1|id=17
# p_no=4|index=1|id=20
# p_no=3|index=1|id=2
# p_no=5|index=1|id=21
# p_no=2|index=1|id=18
# p_no=6|index=1|id=22
# p_no=1|index=2|id=23
# p_no=5|index=2|id=28
# p_no=4|index=2|id=27
# p_no=3|index=2|id=26
# p_no=6|index=2|id=29
# p_no=2|index=2|id=25
# p_no=1|index=3|id=3
# p_no=4|index=3|id=32
# p_no=5|index=3|id=33
# p_no=3|index=3|id=31
# p_no=6|index=3|id=34
# p_no=2|index=3|id=30
# p_no=1|index=4|id=35
# p_no=5|index=4|id=8
# p_no=4|index=4|id=7
# p_no=3|index=4|id=6
# p_no=2|index=4|id=5
# p_no=6|index=4|id=9
# 1 done| [10 17 23  3 35]
# 5 done| [15 21 28 33  8]
# 6 done| [16 22 29 34  9]
# 3 done| [13  2 26 31  6]
# 4 done| [14 20 27 32  7]
# 2 done| [12 18 25 30  5]
# (1500, 8, 65) (1500, 6)
# ========= close ========

# %%
X,Y = shuffle(X,Y)
bands = []
for filt in filter_list:
    pt = np.argwhere((freq >= filt[0]) & (freq <= filt[1])).reshape(-1)
    bands.append(pt)
bands = np.array(bands)

result_audio = []
best_audio = 0
best_audio_idx = -1
best_audio_comb = None
for r in [1,2,3,4,5]:
    print("="*20,f"Number {r}","="*20)
    for comb in combinations([0,1,2,3,4],r):
        print(" ",band_names[list(comb)])
        selected_x = None
        # print(bands[ list(comb) ])
        for pt in bands[ list(comb) ]:
            # print(pt)
            if(type(selected_x) == type(None)): selected_x = X[:,:,pt].mean(axis=2)
            else:
                selected_x = np.concatenate([selected_x, X[:,:,pt].mean(axis=2)], axis=1)
        # print(selected_x.shape)
        # pts = np.concatenate( bands[ list(comb) ] )
        result = np.array(get_accuracy(selected_x,Y))
        print(" Averag accuracy:", result[:,0].mean(), "Average Score:", result[:,1].mean()), "Average Variance:", result[:,2].mean()
        result_audio.append(result)
        if(result[:,1].mean() > best_audio):
            best_audio = result[:,1].mean()
            best_audio_idx = len(result_audio)-1
            best_audio_comb = band_names[ list(comb) ]

print(f"Best Score is {best_audio} at index {best_audio_idx} with combination {best_audio_comb}")
# Out:
# /tmp/ipykernel_32138/2490288531.py:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   bands = np.array(bands)
# ==================== Number 1 ====================
#   ['Delta']
# h | Accuracy: 0.52 Scores: 0.51 (+/- 0.03)
# e | Accuracy: 0.61 Scores: 0.60 (+/- 0.06)
# x | Accuracy: 0.54 Scores: 0.54 (+/- 0.07)
# a | Accuracy: 0.53 Scores: 0.52 (+/- 0.07)
# c | Accuracy: 0.58 Scores: 0.57 (+/- 0.02)
# o | Accuracy: 0.57 Scores: 0.57 (+/- 0.07)
#  Averag accuracy: 0.5588888888888889 Average Score: 0.5537777777777778
#   ['Theta']
# h | Accuracy: 0.52 Scores: 0.51 (+/- 0.04)
# e | Accuracy: 0.58 Scores: 0.57 (+/- 0.04)
# x | Accuracy: 0.55 Scores: 0.54 (+/- 0.02)
# a | Accuracy: 0.54 Scores: 0.53 (+/- 0.05)
# c | Accuracy: 0.59 Scores: 0.57 (+/- 0.05)
# o | Accuracy: 0.55 Scores: 0.56 (+/- 0.04)
#  Averag accuracy: 0.5551111111111111 Average Score: 0.5451111111111112
#   ['Alpha']
# h | Accuracy: 0.54 Scores: 0.52 (+/- 0.05)
# e | Accuracy: 0.58 Scores: 0.57 (+/- 0.04)
# x | Accuracy: 0.58 Scores: 0.58 (+/- 0.04)
# a | Accuracy: 0.58 Scores: 0.58 (+/- 0.05)
# c | Accuracy: 0.56 Scores: 0.55 (+/- 0.03)
# o | Accuracy: 0.57 Scores: 0.56 (+/- 0.05)
#  Averag accuracy: 0.5694444444444445 Average Score: 0.5607777777777778
#   ['Beta']
# h | Accuracy: 0.58 Scores: 0.57 (+/- 0.06)
# e | Accuracy: 0.58 Scores: 0.57 (+/- 0.04)
# x | Accuracy: 0.56 Scores: 0.56 (+/- 0.06)
# a | Accuracy: 0.60 Scores: 0.60 (+/- 0.07)
# c | Accuracy: 0.65 Scores: 0.64 (+/- 0.04)
# o | Accuracy: 0.60 Scores: 0.59 (+/- 0.03)
#  Averag accuracy: 0.5933333333333334 Average Score: 0.5884444444444444
#   ['Gamma']
# h | Accuracy: 0.55 Scores: 0.55 (+/- 0.06)
# e | Accuracy: 0.60 Scores: 0.60 (+/- 0.04)
# x | Accuracy: 0.63 Scores: 0.62 (+/- 0.04)
# a | Accuracy: 0.62 Scores: 0.62 (+/- 0.06)
# c | Accuracy: 0.70 Scores: 0.70 (+/- 0.04)
# o | Accuracy: 0.67 Scores: 0.66 (+/- 0.04)
#  Averag accuracy: 0.628 Average Score: 0.6265555555555556
# ==================== Number 2 ====================
#   ['Delta' 'Theta']
# h | Accuracy: 0.53 Scores: 0.52 (+/- 0.02)
# e | Accuracy: 0.58 Scores: 0.57 (+/- 0.03)
# x | Accuracy: 0.57 Scores: 0.55 (+/- 0.07)
# a | Accuracy: 0.56 Scores: 0.55 (+/- 0.07)
# c | Accuracy: 0.57 Scores: 0.57 (+/- 0.02)
# o | Accuracy: 0.58 Scores: 0.57 (+/- 0.05)
#  Averag accuracy: 0.5642222222222222 Average Score: 0.5541111111111111
#   ['Delta' 'Alpha']
# h | Accuracy: 0.53 Scores: 0.52 (+/- 0.09)
# e | Accuracy: 0.60 Scores: 0.58 (+/- 0.02)
# x | Accuracy: 0.59 Scores: 0.58 (+/- 0.04)
# a | Accuracy: 0.58 Scores: 0.57 (+/- 0.04)
# c | Accuracy: 0.58 Scores: 0.57 (+/- 0.03)
# o | Accuracy: 0.60 Scores: 0.59 (+/- 0.05)
#  Averag accuracy: 0.5794444444444445 Average Score: 0.5674444444444444
#   ['Delta' 'Beta']
# h | Accuracy: 0.57 Scores: 0.55 (+/- 0.05)
# e | Accuracy: 0.58 Scores: 0.58 (+/- 0.05)
# x | Accuracy: 0.58 Scores: 0.56 (+/- 0.07)
# a | Accuracy: 0.60 Scores: 0.60 (+/- 0.07)
# c | Accuracy: 0.65 Scores: 0.64 (+/- 0.05)
# o | Accuracy: 0.60 Scores: 0.59 (+/- 0.02)
#  Averag accuracy: 0.5970000000000001 Average Score: 0.5865555555555555
#   ['Delta' 'Gamma']
# h | Accuracy: 0.55 Scores: 0.55 (+/- 0.06)
# e | Accuracy: 0.61 Scores: 0.61 (+/- 0.07)
# x | Accuracy: 0.64 Scores: 0.63 (+/- 0.06)
# a | Accuracy: 0.61 Scores: 0.60 (+/- 0.08)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.04)
# o | Accuracy: 0.66 Scores: 0.66 (+/- 0.04)
#  Averag accuracy: 0.6277777777777779 Average Score: 0.6232222222222222
#   ['Theta' 'Alpha']
# h | Accuracy: 0.53 Scores: 0.52 (+/- 0.06)
# e | Accuracy: 0.59 Scores: 0.57 (+/- 0.03)
# x | Accuracy: 0.61 Scores: 0.60 (+/- 0.04)
# a | Accuracy: 0.58 Scores: 0.58 (+/- 0.03)
# c | Accuracy: 0.58 Scores: 0.56 (+/- 0.05)
# o | Accuracy: 0.59 Scores: 0.59 (+/- 0.03)
#  Averag accuracy: 0.5798888888888888 Average Score: 0.5692222222222223
#   ['Theta' 'Beta']
# h | Accuracy: 0.57 Scores: 0.56 (+/- 0.08)
# e | Accuracy: 0.59 Scores: 0.58 (+/- 0.02)
# x | Accuracy: 0.58 Scores: 0.56 (+/- 0.06)
# a | Accuracy: 0.60 Scores: 0.59 (+/- 0.05)
# c | Accuracy: 0.65 Scores: 0.64 (+/- 0.04)
# o | Accuracy: 0.59 Scores: 0.58 (+/- 0.04)
#  Averag accuracy: 0.5981111111111111 Average Score: 0.5867777777777777
#   ['Theta' 'Gamma']
# h | Accuracy: 0.54 Scores: 0.54 (+/- 0.07)
# e | Accuracy: 0.62 Scores: 0.61 (+/- 0.03)
# x | Accuracy: 0.62 Scores: 0.61 (+/- 0.04)
# a | Accuracy: 0.64 Scores: 0.64 (+/- 0.07)
# c | Accuracy: 0.71 Scores: 0.70 (+/- 0.04)
# o | Accuracy: 0.66 Scores: 0.65 (+/- 0.03)
#  Averag accuracy: 0.6317777777777779 Average Score: 0.627
#   ['Alpha' 'Beta']
# h | Accuracy: 0.58 Scores: 0.57 (+/- 0.10)
# e | Accuracy: 0.59 Scores: 0.59 (+/- 0.02)
# x | Accuracy: 0.63 Scores: 0.63 (+/- 0.05)
# a | Accuracy: 0.60 Scores: 0.60 (+/- 0.04)
# c | Accuracy: 0.64 Scores: 0.63 (+/- 0.03)
# o | Accuracy: 0.61 Scores: 0.60 (+/- 0.04)
#  Averag accuracy: 0.608111111111111 Average Score: 0.6033333333333334
#   ['Alpha' 'Gamma']
# h | Accuracy: 0.56 Scores: 0.56 (+/- 0.05)
# e | Accuracy: 0.61 Scores: 0.61 (+/- 0.03)
# x | Accuracy: 0.66 Scores: 0.65 (+/- 0.05)
# a | Accuracy: 0.65 Scores: 0.64 (+/- 0.05)
# c | Accuracy: 0.70 Scores: 0.69 (+/- 0.03)
# o | Accuracy: 0.67 Scores: 0.66 (+/- 0.04)
#  Averag accuracy: 0.6398888888888888 Average Score: 0.634
#   ['Beta' 'Gamma']
# h | Accuracy: 0.58 Scores: 0.57 (+/- 0.08)
# e | Accuracy: 0.61 Scores: 0.60 (+/- 0.04)
# x | Accuracy: 0.62 Scores: 0.61 (+/- 0.06)
# a | Accuracy: 0.65 Scores: 0.64 (+/- 0.05)
# c | Accuracy: 0.70 Scores: 0.70 (+/- 0.03)
# o | Accuracy: 0.66 Scores: 0.65 (+/- 0.03)
#  Averag accuracy: 0.6346666666666666 Average Score: 0.6284444444444444
# ==================== Number 3 ====================
#   ['Delta' 'Theta' 'Alpha']
# h | Accuracy: 0.52 Scores: 0.52 (+/- 0.05)
# e | Accuracy: 0.60 Scores: 0.58 (+/- 0.02)
# x | Accuracy: 0.61 Scores: 0.61 (+/- 0.07)
# a | Accuracy: 0.57 Scores: 0.57 (+/- 0.04)
# c | Accuracy: 0.57 Scores: 0.57 (+/- 0.03)
# o | Accuracy: 0.61 Scores: 0.60 (+/- 0.05)
#  Averag accuracy: 0.5830000000000001 Average Score: 0.573888888888889
#   ['Delta' 'Theta' 'Beta']
# h | Accuracy: 0.56 Scores: 0.55 (+/- 0.05)
# e | Accuracy: 0.58 Scores: 0.57 (+/- 0.03)
# x | Accuracy: 0.59 Scores: 0.57 (+/- 0.08)
# a | Accuracy: 0.59 Scores: 0.59 (+/- 0.07)
# c | Accuracy: 0.65 Scores: 0.64 (+/- 0.03)
# o | Accuracy: 0.59 Scores: 0.58 (+/- 0.04)
#  Averag accuracy: 0.5925555555555555 Average Score: 0.583888888888889
#   ['Delta' 'Theta' 'Gamma']
# h | Accuracy: 0.55 Scores: 0.54 (+/- 0.05)
# e | Accuracy: 0.62 Scores: 0.62 (+/- 0.03)
# x | Accuracy: 0.63 Scores: 0.62 (+/- 0.08)
# a | Accuracy: 0.63 Scores: 0.61 (+/- 0.08)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.04)
# o | Accuracy: 0.66 Scores: 0.65 (+/- 0.05)
#  Averag accuracy: 0.6302222222222222 Average Score: 0.6207777777777779
#   ['Delta' 'Alpha' 'Beta']
# h | Accuracy: 0.57 Scores: 0.56 (+/- 0.08)
# e | Accuracy: 0.60 Scores: 0.59 (+/- 0.03)
# x | Accuracy: 0.65 Scores: 0.65 (+/- 0.06)
# a | Accuracy: 0.61 Scores: 0.59 (+/- 0.03)
# c | Accuracy: 0.64 Scores: 0.64 (+/- 0.05)
# o | Accuracy: 0.63 Scores: 0.62 (+/- 0.03)
#  Averag accuracy: 0.6172222222222222 Average Score: 0.6075555555555555
#   ['Delta' 'Alpha' 'Gamma']
# h | Accuracy: 0.56 Scores: 0.56 (+/- 0.06)
# e | Accuracy: 0.61 Scores: 0.61 (+/- 0.05)
# x | Accuracy: 0.67 Scores: 0.66 (+/- 0.06)
# a | Accuracy: 0.63 Scores: 0.62 (+/- 0.07)
# c | Accuracy: 0.69 Scores: 0.68 (+/- 0.04)
# o | Accuracy: 0.66 Scores: 0.66 (+/- 0.04)
#  Averag accuracy: 0.6381111111111112 Average Score: 0.6309999999999999
#   ['Delta' 'Beta' 'Gamma']
# h | Accuracy: 0.58 Scores: 0.57 (+/- 0.06)
# e | Accuracy: 0.61 Scores: 0.61 (+/- 0.06)
# x | Accuracy: 0.63 Scores: 0.61 (+/- 0.05)
# a | Accuracy: 0.64 Scores: 0.63 (+/- 0.07)
# c | Accuracy: 0.70 Scores: 0.70 (+/- 0.03)
# o | Accuracy: 0.66 Scores: 0.66 (+/- 0.03)
#  Averag accuracy: 0.6354444444444444 Average Score: 0.628
#   ['Theta' 'Alpha' 'Beta']
# h | Accuracy: 0.57 Scores: 0.56 (+/- 0.12)
# e | Accuracy: 0.59 Scores: 0.59 (+/- 0.03)
# x | Accuracy: 0.64 Scores: 0.62 (+/- 0.05)
# a | Accuracy: 0.61 Scores: 0.60 (+/- 0.03)
# c | Accuracy: 0.64 Scores: 0.63 (+/- 0.04)
# o | Accuracy: 0.61 Scores: 0.60 (+/- 0.03)
#  Averag accuracy: 0.6105555555555555 Average Score: 0.6014444444444444
#   ['Theta' 'Alpha' 'Gamma']
# h | Accuracy: 0.56 Scores: 0.54 (+/- 0.06)
# e | Accuracy: 0.63 Scores: 0.61 (+/- 0.03)
# x | Accuracy: 0.66 Scores: 0.65 (+/- 0.08)
# a | Accuracy: 0.64 Scores: 0.63 (+/- 0.04)
# c | Accuracy: 0.70 Scores: 0.69 (+/- 0.03)
# o | Accuracy: 0.66 Scores: 0.65 (+/- 0.04)
#  Averag accuracy: 0.6404444444444444 Average Score: 0.6302222222222222
#   ['Theta' 'Beta' 'Gamma']
# h | Accuracy: 0.56 Scores: 0.57 (+/- 0.10)
# e | Accuracy: 0.61 Scores: 0.61 (+/- 0.03)
# x | Accuracy: 0.61 Scores: 0.60 (+/- 0.06)
# a | Accuracy: 0.65 Scores: 0.64 (+/- 0.04)
# c | Accuracy: 0.70 Scores: 0.69 (+/- 0.04)
# o | Accuracy: 0.65 Scores: 0.65 (+/- 0.01)
#  Averag accuracy: 0.63 Average Score: 0.6266666666666666
#   ['Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.59 Scores: 0.57 (+/- 0.09)
# e | Accuracy: 0.61 Scores: 0.61 (+/- 0.05)
# x | Accuracy: 0.64 Scores: 0.64 (+/- 0.06)
# a | Accuracy: 0.65 Scores: 0.64 (+/- 0.05)
# c | Accuracy: 0.69 Scores: 0.70 (+/- 0.02)
# o | Accuracy: 0.67 Scores: 0.66 (+/- 0.02)
#  Averag accuracy: 0.6395555555555555 Average Score: 0.6356666666666667
# ==================== Number 4 ====================
#   ['Delta' 'Theta' 'Alpha' 'Beta']
# h | Accuracy: 0.56 Scores: 0.56 (+/- 0.09)
# e | Accuracy: 0.59 Scores: 0.58 (+/- 0.03)
# x | Accuracy: 0.67 Scores: 0.64 (+/- 0.07)
# a | Accuracy: 0.61 Scores: 0.60 (+/- 0.04)
# c | Accuracy: 0.64 Scores: 0.63 (+/- 0.04)
# o | Accuracy: 0.62 Scores: 0.61 (+/- 0.03)
#  Averag accuracy: 0.6146666666666666 Average Score: 0.6042222222222222
#   ['Delta' 'Theta' 'Alpha' 'Gamma']
# h | Accuracy: 0.56 Scores: 0.55 (+/- 0.06)
# e | Accuracy: 0.62 Scores: 0.62 (+/- 0.04)
# x | Accuracy: 0.67 Scores: 0.66 (+/- 0.09)
# a | Accuracy: 0.63 Scores: 0.62 (+/- 0.06)
# c | Accuracy: 0.69 Scores: 0.68 (+/- 0.03)
# o | Accuracy: 0.67 Scores: 0.65 (+/- 0.03)
#  Averag accuracy: 0.6405555555555555 Average Score: 0.6288888888888889
#   ['Delta' 'Theta' 'Beta' 'Gamma']
# h | Accuracy: 0.57 Scores: 0.56 (+/- 0.06)
# e | Accuracy: 0.61 Scores: 0.61 (+/- 0.05)
# x | Accuracy: 0.62 Scores: 0.61 (+/- 0.05)
# a | Accuracy: 0.64 Scores: 0.63 (+/- 0.05)
# c | Accuracy: 0.70 Scores: 0.70 (+/- 0.03)
# o | Accuracy: 0.65 Scores: 0.65 (+/- 0.04)
#  Averag accuracy: 0.6312222222222221 Average Score: 0.6254444444444444
#   ['Delta' 'Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.57 Scores: 0.57 (+/- 0.08)
# e | Accuracy: 0.61 Scores: 0.61 (+/- 0.05)
# x | Accuracy: 0.65 Scores: 0.64 (+/- 0.08)
# a | Accuracy: 0.64 Scores: 0.63 (+/- 0.08)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.03)
# o | Accuracy: 0.66 Scores: 0.66 (+/- 0.04)
#  Averag accuracy: 0.6377777777777777 Average Score: 0.6330000000000001
#   ['Theta' 'Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.58 Scores: 0.56 (+/- 0.10)
# e | Accuracy: 0.62 Scores: 0.61 (+/- 0.04)
# x | Accuracy: 0.64 Scores: 0.63 (+/- 0.06)
# a | Accuracy: 0.65 Scores: 0.63 (+/- 0.04)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.03)
# o | Accuracy: 0.66 Scores: 0.65 (+/- 0.02)
#  Averag accuracy: 0.6397777777777778 Average Score: 0.6293333333333334
# ==================== Number 5 ====================
#   ['Delta' 'Theta' 'Alpha' 'Beta' 'Gamma']
# h | Accuracy: 0.57 Scores: 0.57 (+/- 0.07)
# e | Accuracy: 0.62 Scores: 0.61 (+/- 0.05)
# x | Accuracy: 0.66 Scores: 0.64 (+/- 0.08)
# a | Accuracy: 0.63 Scores: 0.63 (+/- 0.07)
# c | Accuracy: 0.69 Scores: 0.69 (+/- 0.03)
# o | Accuracy: 0.66 Scores: 0.65 (+/- 0.04)
#  Averag accuracy: 0.6385555555555554 Average Score: 0.6316666666666667
# Best Score is 0.6356666666666667 at index 24 with combination ['Alpha' 'Beta' 'Gamma']

# %%
result_image = np.array(result_image)
result_audio = np.array(result_audio)

# %%
result_audio.shape
# Out:
# (31, 6, 3)

# %%
traits = ["h","e","x","a","c","o"]
width =.35

fig, ax = plt.subplots(figsize=(12,8))

ax.bar(np.arange(6)      ,result_image[best_image_idx,:,0] * 100, width=width, label='image', ecolor='black', capsize=10)
ax.bar(np.arange(6)+width,result_audio[best_audio_idx,:,0] * 100, width=width, label='audio', ecolor='black', capsize=10)

ax.set_xlabel('Traits')
ax.set_ylabel('Accuracy (%)')
ax.set_title('Accuracy of each trait prediction')
ax.set_xticks(np.arange(6) + width / 2)
ax.set_xticklabels(traits)
ax.legend()

plt.show()

# %%
print(f"On average, image accuracy is {round(result_image[best_image_idx,:,0].mean(),2)} and audio accuracy is {round(result_audio[best_audio_idx,:,0].mean(),2)}")
print(f"On average, image    score is {round(result_image[best_image_idx,:,1].mean(),2)} and audio    score is {round(result_audio[best_audio_idx,:,1].mean(),2)}")
print(f"On average, image      std is {round(result_image[best_image_idx,:,2].mean(),2)} and audio      std is {round(result_audio[best_audio_idx,:,2].mean(),2)}")
# Out:
# On average, image accuracy is 0.66 and audio accuracy is 0.64
# On average, image    score is 0.65 and audio    score is 0.64
# On average, image      std is 0.03 and audio      std is 0.02

# %%
for index, trait in enumerate(traits):
    print(f"Image {trait}: Acc: {round(result_image[best_image_idx,index,0],2)} | score: {round(result_image[best_image_idx,index,1],2)} | std: score: {round(result_image[best_image_idx,index,2],2)}" )
    print(f"Audio {trait}: Acc: {round(result_audio[best_audio_idx,index,0],2)} | score: {round(result_audio[best_audio_idx,index,1],2)} | std: score: {round(result_audio[best_audio_idx,index,2],2)}" )
    print()
print(f"Image: Best Score is {best_image} at index {best_image_idx} with combination {best_image_comb}")
print(f"Audio: Best Score is {best_audio} at index {best_audio_idx} with combination {best_audio_comb}")
# Out:
# Image h: Acc: 0.7 | score: 0.68 | std: score: 0.02
# Audio h: Acc: 0.59 | score: 0.57 | std: score: 0.05
#
# Image e: Acc: 0.65 | score: 0.63 | std: score: 0.04
# Audio e: Acc: 0.61 | score: 0.61 | std: score: 0.03
#
# Image x: Acc: 0.61 | score: 0.61 | std: score: 0.03
# Audio x: Acc: 0.64 | score: 0.64 | std: score: 0.03
#
# Image a: Acc: 0.65 | score: 0.65 | std: score: 0.02
# Audio a: Acc: 0.65 | score: 0.64 | std: score: 0.03
#
# Image c: Acc: 0.7 | score: 0.7 | std: score: 0.03
# Audio c: Acc: 0.69 | score: 0.7 | std: score: 0.01
#
# Image o: Acc: 0.65 | score: 0.64 | std: score: 0.03
# Audio o: Acc: 0.67 | score: 0.66 | std: score: 0.01
#
# Image: Best Score is 0.6525555555555556 at index 14 with combination ['Beta' 'Gamma']
# Audio: Best Score is 0.6356666666666667 at index 24 with combination ['Alpha' 'Beta' 'Gamma']

# %%
a1 = np.array([0,1,2]).reshape(-1,1)
a2 = np.array([0,1,2]).reshape(-1,1)
a = np.concatenate([a1,a2], axis=1)
print(a)
normalize(a,axis=0)
# Out:
# [[0 0]
#  [1 1]
#  [2 2]]
# array([[0.        , 0.        ],
#        [0.4472136 , 0.4472136 ],
#        [0.89442719, 0.89442719]])
